# %%
#Imports
import json
import joblib
import warnings
import numpy as np
import pandas as pd
import seaborn as sns
from pathlib import Path
import matplotlib.pyplot as plt
from sklearn.model_selection import GridSearchCV, KFold, StratifiedKFold
from sklearn.metrics import (
                            mean_absolute_error, mean_squared_error, r2_score,
                            accuracy_score, precision_score, recall_score, f1_score, confusion_matrix
                            )
from sklearn.ensemble import RandomForestRegressor, RandomForestClassifier
from xgboost import XGBRegressor, XGBClassifier

warnings.filterwarnings('ignore')
print("Import loaded")
# Out:
# Import loaded

# %%
ARTIFACTS_DIR = Path("artifacts")
FIGURES_DIR = Path("artifacts/figures")
N_SPLITS = 5


RANDOM_STATE = 42
np.random.seed(RANDOM_STATE)

# %% [markdown]
# #### 01) Load Preprocessed Arrays

# %%
X_train_reg = np.load(ARTIFACTS_DIR / 'X_train_reg.npz')['data']
X_test_reg = np.load(ARTIFACTS_DIR / 'X_test_reg.npz')['data']
y_train_reg = np.load(ARTIFACTS_DIR / 'y_train_reg.npz')['data']
y_test_reg = np.load(ARTIFACTS_DIR / 'y_test_reg.npz')['data']

X_train_cls = np.load(ARTIFACTS_DIR / 'X_train_cls.npz')['data']
X_test_cls = np.load(ARTIFACTS_DIR / 'X_test_cls.npz')['data']
y_train_cls = np.load(ARTIFACTS_DIR / 'y_train_cls.npz')['data']
y_test_cls = np.load(ARTIFACTS_DIR / 'y_test_cls.npz')['data']

print("Regression arrays loaded:")
print(f"   X_train : {X_train_reg.shape}, X_test : {X_test_reg.shape}")
print(f"   y_train : {y_train_reg.shape}, y_test : {y_test_reg.shape}")

print("\nClassification arrays loaded:")
print(f"   X_train : {X_train_cls.shape}, X_test : {X_test_cls.shape}")
print(f"   y_train : {y_train_cls.shape}, y_test : {y_test_cls.shape}")
# Out:
# Regression arrays loaded:
#    X_train : (36735, 39), X_test : (9177, 39)
#    y_train : (36735,), y_test : (9177,)
#
# Classification arrays loaded:
#    X_train : (36735, 39), X_test : (9177, 39)
#    y_train : (36735,), y_test : (9177,)

# %%
"""
01. What is KFold ?

|-------------------------------------------------------------------------------|
|       F1      |       F2      |       F3      |       F4      |       F5      |
|-------------------------------------------------------------------------------|

Train - Train the Model
Test- Test model performance
Validation - Hyper Parameter Tuning

F1, F2, F3, F4 - Train, F5 - Validation
F1, F2, F3, F5 - Train, F4 - Validation
F1, F2, F4, F5 - Train, F3 - Validation 
....

02. What is StratifiedKFold ?

This comes in Handy when your dataset is Class Imbalanced ...
Total Sample Count - 16
Two Classses : A & B , A - 12 , B -4
N_SPLITS = 4 (Each split consist of 4)
Kfold the problem is it won't account pproportions. But StratifiedKFold solve this issue.

A : B = 3 : 1

with this everytime it create a split which satisfy A : B


"""
# Out:
# "\n01. What is KFold ?\n\n|-------------------------------------------------------------------------------|\n|       F1      |       F2      |       F3      |       F4      |       F5      |\n|-------------------------------------------------------------------------------|\n\nTrain - Train the Model\nTest- Test model performance\nValidation - Hyper Parameter Tuning\n\nF1, F2, F3, F4 - Train, F5 - Validation\nF1, F2, F3, F5 - Train, F4 - Validation\nF1, F2, F4, F5 - Train, F3 - Validation \n....\n\n02. What is StratifiedKFold ?\n\nThis comes in Handy when your dataset is Class Imbalanced ...\nTotal Sample Count - 16\nTwo Classses : A & B , A - 12 , B -4\nN_SPLITS = 4 (Each split consist of 4)\nKfold the problem is it won't account pproportions. But StratifiedKFold solve this issue.\n\nA : B = 3 : 1\n\nwith this everytime it create a split which satisfy A : B\n\n\n"

# %% [markdown]
# #### 02) Regression Hparam Tuning

# %%
param_grids_regg = {
    
                    'RF' : {
                            'model' : RandomForestRegressor(random_state=RANDOM_STATE),
                            'params' : {
                                        'n_estimators' : [100, 200],
                                        'min_samples_leaf' : [1, 5],
                                        'max_depth' : [6, 8, 12]
                                        }
                    },
                    'XGB' : {
                            'model' : XGBRegressor(random_state=RANDOM_STATE),
                            'params' : {
                                        'n_estimators' : [50, 100, 200],
                                        'learning_rate' : [0.05, 0.1],
                                        'max_depth' : [8, 10, 12]
                                        }
                    }
                }

kf = KFold(
        n_splits=N_SPLITS,
        shuffle=True, random_state=RANDOM_STATE       
        )

reg_tuning_results = {}
for name, config in param_grids_regg.items():
    print(f"\n Training {name} model...")

#Grid Search Cross Validation
    grid_search = GridSearchCV(
                        estimator=config['model'],
                        param_grid=config['params'],
                        cv=kf, scoring='neg_root_mean_squared_error',
                        verbose=3
                     )
    grid_search.fit(X_train_reg, y_train_reg)

    reg_tuning_results[name] = {
                                'best_params' : grid_search.best_params_,
                                'best_cv_score' : grid_search.best_score_,
                                'best_estimator' : grid_search.best_estimator_
                                }
    
    print(f"    Best Params : {grid_search.best_params_}")
    print(f"    Best Estimators : {grid_search.best_estimator_}")

print("\n regression Tuning Summary")
for name, result in reg_tuning_results.items():
    print(f"    {name} : RMSE=${result['best_cv_score']:.2f} |  params={result['best_params']}")
# Out:
#  Training RF model...
# Fitting 5 folds for each of 12 candidates, totalling 60 fits
# [CV 1/5] END max_depth=6, min_samples_leaf=1, n_estimators=100;, score=-45.677 total time=   5.7s
# [CV 2/5] END max_depth=6, min_samples_leaf=1, n_estimators=100;, score=-46.547 total time=   5.6s
# [CV 3/5] END max_depth=6, min_samples_leaf=1, n_estimators=100;, score=-46.037 total time=   6.0s
# [CV 4/5] END max_depth=6, min_samples_leaf=1, n_estimators=100;, score=-45.985 total time=   5.6s
# [CV 5/5] END max_depth=6, min_samples_leaf=1, n_estimators=100;, score=-45.391 total time=   5.6s
# [CV 1/5] END max_depth=6, min_samples_leaf=1, n_estimators=200;, score=-45.673 total time=  11.2s
# [CV 2/5] END max_depth=6, min_samples_leaf=1, n_estimators=200;, score=-46.528 total time=  11.4s
# [CV 3/5] END max_depth=6, min_samples_leaf=1, n_estimators=200;, score=-46.037 total time=  11.5s
# [CV 4/5] END max_depth=6, min_samples_leaf=1, n_estimators=200;, score=-45.989 total time=  11.3s
# [CV 5/5] END max_depth=6, min_samples_leaf=1, n_estimators=200;, score=-45.402 total time=  11.2s
# [CV 1/5] END max_depth=6, min_samples_leaf=5, n_estimators=100;, score=-45.651 total time=   5.4s
# [CV 2/5] END max_depth=6, min_samples_leaf=5, n_estimators=100;, score=-46.519 total time=   5.5s
# [CV 3/5] END max_depth=6, min_samples_leaf=5, n_estimators=100;, score=-46.023 total time=   5.5s
# [CV 4/5] END max_depth=6, min_samples_leaf=5, n_estimators=100;, score=-45.947 total time=   5.5s
# [CV 5/5] END max_depth=6, min_samples_leaf=5, n_estimators=100;, score=-45.371 total time=   5.4s
# [CV 1/5] END max_depth=6, min_samples_leaf=5, n_estimators=200;, score=-45.647 total time=  11.0s
# [CV 2/5] END max_depth=6, min_samples_leaf=5, n_estimators=200;, score=-46.498 total time=  11.8s
# [CV 3/5] END max_depth=6, min_samples_leaf=5, n_estimators=200;, score=-46.018 total time=  11.5s
# [CV 4/5] END max_depth=6, min_samples_leaf=5, n_estimators=200;, score=-45.946 total time=  10.9s
# [CV 5/5] END max_depth=6, min_samples_leaf=5, n_estimators=200;, score=-45.384 total time=  10.7s
# [CV 1/5] END max_depth=8, min_samples_leaf=1, n_estimators=100;, score=-44.836 total time=   6.9s
# [CV 2/5] END max_depth=8, min_samples_leaf=1, n_estimators=100;, score=-45.777 total time=   6.9s
# [CV 3/5] END max_depth=8, min_samples_leaf=1, n_estimators=100;, score=-45.105 total time=   7.0s
# [CV 4/5] END max_depth=8, min_samples_leaf=1, n_estimators=100;, score=-45.145 total time=   6.9s
# [CV 5/5] END max_depth=8, min_samples_leaf=1, n_estimators=100;, score=-44.475 total time=   6.9s
# [CV 1/5] END max_depth=8, min_samples_leaf=1, n_estimators=200;, score=-44.831 total time=  13.7s
# [CV 2/5] END max_depth=8, min_samples_leaf=1, n_estimators=200;, score=-45.749 total time=  13.9s
# [CV 3/5] END max_depth=8, min_samples_leaf=1, n_estimators=200;, score=-45.099 total time=  14.1s
# [CV 4/5] END max_depth=8, min_samples_leaf=1, n_estimators=200;, score=-45.141 total time=  14.4s
# [CV 5/5] END max_depth=8, min_samples_leaf=1, n_estimators=200;, score=-44.470 total time=  13.9s
# [CV 1/5] END max_depth=8, min_samples_leaf=5, n_estimators=100;, score=-44.770 total time=   7.0s
# [CV 2/5] END max_depth=8, min_samples_leaf=5, n_estimators=100;, score=-45.687 total time=   6.9s
# [CV 3/5] END max_depth=8, min_samples_leaf=5, n_estimators=100;, score=-45.076 total time=   7.0s
# [CV 4/5] END max_depth=8, min_samples_leaf=5, n_estimators=100;, score=-45.086 total time=   6.9s
# [CV 5/5] END max_depth=8, min_samples_leaf=5, n_estimators=100;, score=-44.434 total time=   7.0s
# [CV 1/5] END max_depth=8, min_samples_leaf=5, n_estimators=200;, score=-44.768 total time=  13.9s
# [CV 2/5] END max_depth=8, min_samples_leaf=5, n_estimators=200;, score=-45.676 total time=  14.0s
# [CV 3/5] END max_depth=8, min_samples_leaf=5, n_estimators=200;, score=-45.064 total time=  14.0s
# [CV 4/5] END max_depth=8, min_samples_leaf=5, n_estimators=200;, score=-45.093 total time=  13.9s
# [CV 5/5] END max_depth=8, min_samples_leaf=5, n_estimators=200;, score=-44.432 total time=  13.8s
# [CV 1/5] END max_depth=12, min_samples_leaf=1, n_estimators=100;, score=-43.960 total time=  10.0s
# [CV 2/5] END max_depth=12, min_samples_leaf=1, n_estimators=100;, score=-45.019 total time=  10.0s
# [CV 3/5] END max_depth=12, min_samples_leaf=1, n_estimators=100;, score=-44.239 total time=  10.1s
# [CV 4/5] END max_depth=12, min_samples_leaf=1, n_estimators=100;, score=-44.322 total time=  10.0s
# [CV 5/5] END max_depth=12, min_samples_leaf=1, n_estimators=100;, score=-43.705 total time=  10.1s
# [CV 1/5] END max_depth=12, min_samples_leaf=1, n_estimators=200;, score=-43.891 total time=  20.2s
# [CV 2/5] END max_depth=12, min_samples_leaf=1, n_estimators=200;, score=-44.949 total time=  19.9s
# [CV 3/5] END max_depth=12, min_samples_leaf=1, n_estimators=200;, score=-44.199 total time=  19.6s
# [CV 4/5] END max_depth=12, min_samples_leaf=1, n_estimators=200;, score=-44.300 total time=  19.7s
# [CV 5/5] END max_depth=12, min_samples_leaf=1, n_estimators=200;, score=-43.678 total time=  19.8s
# [CV 1/5] END max_depth=12, min_samples_leaf=5, n_estimators=100;, score=-43.796 total time=   9.8s
# [CV 2/5] END max_depth=12, min_samples_leaf=5, n_estimators=100;, score=-44.886 total time=   9.7s
# [CV 3/5] END max_depth=12, min_samples_leaf=5, n_estimators=100;, score=-44.186 total time=   9.6s
# [CV 4/5] END max_depth=12, min_samples_leaf=5, n_estimators=100;, score=-44.186 total time=  10.2s
# [CV 5/5] END max_depth=12, min_samples_leaf=5, n_estimators=100;, score=-43.598 total time=   9.9s
# [CV 1/5] END max_depth=12, min_samples_leaf=5, n_estimators=200;, score=-43.779 total time=  19.7s
# [CV 2/5] END max_depth=12, min_samples_leaf=5, n_estimators=200;, score=-44.850 total time=  19.4s
# [CV 3/5] END max_depth=12, min_samples_leaf=5, n_estimators=200;, score=-44.170 total time=  19.1s
# [CV 4/5] END max_depth=12, min_samples_leaf=5, n_estimators=200;, score=-44.194 total time=  19.3s
# [CV 5/5] END max_depth=12, min_samples_leaf=5, n_estimators=200;, score=-43.589 total time=  19.9s
#     Best Params : {'max_depth': 12, 'min_samples_leaf': 5, 'n_estimators': 200}
#     Best Estimators : RandomForestRegressor(max_depth=12, min_samples_leaf=5, n_estimators=200,
#                       random_state=42)
#
#  Training XGB model...
# Fitting 5 folds for each of 18 candidates, totalling 90 fits
# [CV 1/5] END max_depth=6, min_samples_leaf=0.05, n_estimators=50;, score=-43.735 total time=   1.7s
# [CV 2/5] END max_depth=6, min_samples_leaf=0.05, n_estimators=50;, score=-44.740 total time=   0.0s
# [CV 3/5] END max_depth=6, min_samples_leaf=0.05, n_estimators=50;, score=-44.135 total time=   0.0s
# [CV 4/5] END max_depth=6, min_samples_leaf=0.05, n_estimators=50;, score=-44.562 total time=   0.0s
# [CV 5/5] END max_depth=6, min_samples_leaf=0.05, n_estimators=50;, score=-43.684 total time=   0.0s
# [CV 1/5] END max_depth=6, min_samples_leaf=0.05, n_estimators=100;, score=-43.906 total time=   0.1s
# [CV 2/5] END max_depth=6, min_samples_leaf=0.05, n_estimators=100;, score=-45.021 total time=   0.2s
# [CV 3/5] END max_depth=6, min_samples_leaf=0.05, n_estimators=100;, score=-44.329 total time=   0.2s
# [CV 4/5] END max_depth=6, min_samples_leaf=0.05, n_estimators=100;, score=-44.864 total time=   0.2s
# [CV 5/5] END max_depth=6, min_samples_leaf=0.05, n_estimators=100;, score=-44.147 total time=   0.2s
# [CV 1/5] END max_depth=6, min_samples_leaf=0.05, n_estimators=200;, score=-44.448 total time=   0.4s
# [CV 2/5] END max_depth=6, min_samples_leaf=0.05, n_estimators=200;, score=-45.743 total time=   0.3s
# [CV 3/5] END max_depth=6, min_samples_leaf=0.05, n_estimators=200;, score=-44.829 total time=   0.4s
# [CV 4/5] END max_depth=6, min_samples_leaf=0.05, n_estimators=200;, score=-45.561 total time=   0.3s
# [CV 5/5] END max_depth=6, min_samples_leaf=0.05, n_estimators=200;, score=-44.660 total time=   0.2s
# [CV 1/5] END max_depth=6, min_samples_leaf=0.1, n_estimators=50;, score=-43.735 total time=   0.0s
# [CV 2/5] END max_depth=6, min_samples_leaf=0.1, n_estimators=50;, score=-44.740 total time=   0.0s
# [CV 3/5] END max_depth=6, min_samples_leaf=0.1, n_estimators=50;, score=-44.135 total time=   0.0s
# [CV 4/5] END max_depth=6, min_samples_leaf=0.1, n_estimators=50;, score=-44.562 total time=   0.0s
# [CV 5/5] END max_depth=6, min_samples_leaf=0.1, n_estimators=50;, score=-43.684 total time=   0.0s
# [CV 1/5] END max_depth=6, min_samples_leaf=0.1, n_estimators=100;, score=-43.906 total time=   0.1s
# [CV 2/5] END max_depth=6, min_samples_leaf=0.1, n_estimators=100;, score=-45.021 total time=   0.1s
# [CV 3/5] END max_depth=6, min_samples_leaf=0.1, n_estimators=100;, score=-44.329 total time=   0.1s
# [CV 4/5] END max_depth=6, min_samples_leaf=0.1, n_estimators=100;, score=-44.864 total time=   0.1s
# [CV 5/5] END max_depth=6, min_samples_leaf=0.1, n_estimators=100;, score=-44.147 total time=   0.1s
# [CV 1/5] END max_depth=6, min_samples_leaf=0.1, n_estimators=200;, score=-44.448 total time=   0.2s
# [CV 2/5] END max_depth=6, min_samples_leaf=0.1, n_estimators=200;, score=-45.743 total time=   0.3s
# [CV 3/5] END max_depth=6, min_samples_leaf=0.1, n_estimators=200;, score=-44.829 total time=   0.2s
# [CV 4/5] END max_depth=6, min_samples_leaf=0.1, n_estimators=200;, score=-45.561 total time=   0.4s
# [CV 5/5] END max_depth=6, min_samples_leaf=0.1, n_estimators=200;, score=-44.660 total time=   0.4s
# [CV 1/5] END max_depth=12, min_samples_leaf=0.05, n_estimators=50;, score=-46.046 total time=   0.9s
# [CV 2/5] END max_depth=12, min_samples_leaf=0.05, n_estimators=50;, score=-47.020 total time=   0.8s
# [CV 3/5] END max_depth=12, min_samples_leaf=0.05, n_estimators=50;, score=-46.517 total time=   0.6s
# [CV 4/5] END max_depth=12, min_samples_leaf=0.05, n_estimators=50;, score=-46.270 total time=   0.6s
# [CV 5/5] END max_depth=12, min_samples_leaf=0.05, n_estimators=50;, score=-45.967 total time=   0.6s
# [CV 1/5] END max_depth=12, min_samples_leaf=0.05, n_estimators=100;, score=-46.626 total time=   0.9s
# [CV 2/5] END max_depth=12, min_samples_leaf=0.05, n_estimators=100;, score=-47.607 total time=   1.0s
# [CV 3/5] END max_depth=12, min_samples_leaf=0.05, n_estimators=100;, score=-47.005 total time=   1.2s
# [CV 4/5] END max_depth=12, min_samples_leaf=0.05, n_estimators=100;, score=-46.759 total time=   1.3s
# [CV 5/5] END max_depth=12, min_samples_leaf=0.05, n_estimators=100;, score=-46.487 total time=   1.4s
# [CV 1/5] END max_depth=12, min_samples_leaf=0.05, n_estimators=200;, score=-47.063 total time=   2.4s
# [CV 2/5] END max_depth=12, min_samples_leaf=0.05, n_estimators=200;, score=-47.975 total time=   2.3s
# [CV 3/5] END max_depth=12, min_samples_leaf=0.05, n_estimators=200;, score=-47.369 total time=   2.6s
# [CV 4/5] END max_depth=12, min_samples_leaf=0.05, n_estimators=200;, score=-47.141 total time=   2.3s
# [CV 5/5] END max_depth=12, min_samples_leaf=0.05, n_estimators=200;, score=-46.934 total time=   2.0s
# [CV 1/5] END max_depth=12, min_samples_leaf=0.1, n_estimators=50;, score=-46.046 total time=   0.6s
# [CV 2/5] END max_depth=12, min_samples_leaf=0.1, n_estimators=50;, score=-47.020 total time=   0.6s
# [CV 3/5] END max_depth=12, min_samples_leaf=0.1, n_estimators=50;, score=-46.517 total time=   0.5s
# [CV 4/5] END max_depth=12, min_samples_leaf=0.1, n_estimators=50;, score=-46.270 total time=   0.5s
# [CV 5/5] END max_depth=12, min_samples_leaf=0.1, n_estimators=50;, score=-45.967 total time=   0.5s
# [CV 1/5] END max_depth=12, min_samples_leaf=0.1, n_estimators=100;, score=-46.626 total time=   1.1s
# [CV 2/5] END max_depth=12, min_samples_leaf=0.1, n_estimators=100;, score=-47.607 total time=   1.6s
# [CV 3/5] END max_depth=12, min_samples_leaf=0.1, n_estimators=100;, score=-47.005 total time=   1.3s
# [CV 4/5] END max_depth=12, min_samples_leaf=0.1, n_estimators=100;, score=-46.759 total time=   1.1s
# [CV 5/5] END max_depth=12, min_samples_leaf=0.1, n_estimators=100;, score=-46.487 total time=   1.1s
# [CV 1/5] END max_depth=12, min_samples_leaf=0.1, n_estimators=200;, score=-47.063 total time=   2.7s
# [CV 2/5] END max_depth=12, min_samples_leaf=0.1, n_estimators=200;, score=-47.975 total time=   2.5s
# [CV 3/5] END max_depth=12, min_samples_leaf=0.1, n_estimators=200;, score=-47.369 total time=   2.8s
# [CV 4/5] END max_depth=12, min_samples_leaf=0.1, n_estimators=200;, score=-47.141 total time=   1.8s
# [CV 5/5] END max_depth=12, min_samples_leaf=0.1, n_estimators=200;, score=-46.934 total time=   2.7s
# [CV 1/5] END max_depth=28, min_samples_leaf=0.05, n_estimators=50;, score=-47.751 total time=  19.1s
# [CV 2/5] END max_depth=28, min_samples_leaf=0.05, n_estimators=50;, score=-49.113 total time=  16.2s
# [CV 3/5] END max_depth=28, min_samples_leaf=0.05, n_estimators=50;, score=-48.906 total time=  16.0s
# [CV 4/5] END max_depth=28, min_samples_leaf=0.05, n_estimators=50;, score=-49.010 total time=  16.7s
# [CV 5/5] END max_depth=28, min_samples_leaf=0.05, n_estimators=50;, score=-48.140 total time=  15.8s
# [CV 1/5] END max_depth=28, min_samples_leaf=0.05, n_estimators=100;, score=-47.752 total time=  18.7s
# [CV 2/5] END max_depth=28, min_samples_leaf=0.05, n_estimators=100;, score=-49.114 total time=  16.8s
# [CV 3/5] END max_depth=28, min_samples_leaf=0.05, n_estimators=100;, score=-48.907 total time=  16.8s
# [CV 4/5] END max_depth=28, min_samples_leaf=0.05, n_estimators=100;, score=-49.011 total time=  17.9s
# [CV 5/5] END max_depth=28, min_samples_leaf=0.05, n_estimators=100;, score=-48.140 total time=  17.1s
# [CV 1/5] END max_depth=28, min_samples_leaf=0.05, n_estimators=200;, score=-47.752 total time=  18.8s
# [CV 2/5] END max_depth=28, min_samples_leaf=0.05, n_estimators=200;, score=-49.114 total time=  19.2s
# [CV 3/5] END max_depth=28, min_samples_leaf=0.05, n_estimators=200;, score=-48.907 total time=  17.0s
# [CV 4/5] END max_depth=28, min_samples_leaf=0.05, n_estimators=200;, score=-49.011 total time=  17.6s
# [CV 5/5] END max_depth=28, min_samples_leaf=0.05, n_estimators=200;, score=-48.140 total time=  16.5s
# [CV 1/5] END max_depth=28, min_samples_leaf=0.1, n_estimators=50;, score=-47.751 total time=  16.1s
# [CV 2/5] END max_depth=28, min_samples_leaf=0.1, n_estimators=50;, score=-49.113 total time=  15.6s
# [CV 3/5] END max_depth=28, min_samples_leaf=0.1, n_estimators=50;, score=-48.906 total time=  15.2s
# [CV 4/5] END max_depth=28, min_samples_leaf=0.1, n_estimators=50;, score=-49.010 total time=  16.3s
# [CV 5/5] END max_depth=28, min_samples_leaf=0.1, n_estimators=50;, score=-48.140 total time=  14.3s
# [CV 1/5] END max_depth=28, min_samples_leaf=0.1, n_estimators=100;, score=-47.752 total time=  15.0s
# [CV 2/5] END max_depth=28, min_samples_leaf=0.1, n_estimators=100;, score=-49.114 total time=  14.8s
# [CV 3/5] END max_depth=28, min_samples_leaf=0.1, n_estimators=100;, score=-48.907 total time=  14.4s
# [CV 4/5] END max_depth=28, min_samples_leaf=0.1, n_estimators=100;, score=-49.011 total time=  13.9s
# [CV 5/5] END max_depth=28, min_samples_leaf=0.1, n_estimators=100;, score=-48.140 total time=  13.3s
# [CV 1/5] END max_depth=28, min_samples_leaf=0.1, n_estimators=200;, score=-47.752 total time=  14.5s
# [CV 2/5] END max_depth=28, min_samples_leaf=0.1, n_estimators=200;, score=-49.114 total time=  13.9s
# [CV 3/5] END max_depth=28, min_samples_leaf=0.1, n_estimators=200;, score=-48.907 total time=  13.5s
# [CV 4/5] END max_depth=28, min_samples_leaf=0.1, n_estimators=200;, score=-49.011 total time=  13.9s
# [CV 5/5] END max_depth=28, min_samples_leaf=0.1, n_estimators=200;, score=-48.140 total time=  13.4s
#     Best Params : {'max_depth': 6, 'min_samples_leaf': 0.05, 'n_estimators': 50}
#     Best Estimators : XGBRegressor(base_score=None, booster=None, callbacks=None,
#              colsample_bylevel=None, colsample_bynode=None,
#              colsample_bytree=None, device=None, early_stopping_rounds=None,
#              enable_categorical=False, eval_metric=None, feature_types=None,
#              feature_weights=None, gamma=None, grow_policy=None,
#              importance_type=None, interaction_constraints=None,
#              learning_rate=None, max_bin=None, max_cat_threshold=None,
#              max_cat_to_onehot=None, max_delta_step=None, max_depth=6,
#              max_leaves=None, min_child_weight=None, min_samples_leaf=0.05,
#              missing=nan, monotone_constraints=None, multi_strategy=None,
#              n_estimators=50, n_jobs=None, ...)
#
#  regression Tuning Summary
#     RF : RMSE=$-44.12 |  params={'max_depth': 12, 'min_samples_leaf': 5, 'n_estimators': 200}
#     XGB : RMSE=$-44.17 |  params={'max_depth': 6, 'min_samples_leaf': 0.05, 'n_estimators': 50}

# %% [markdown]
# #### 02) Classification Hparam Tuning

# %%
param_grids_cls = {
                    'RF' : {
                            'model' : RandomForestClassifier(random_state=RANDOM_STATE),
                            'params' : {
                                        'n_estimators' : [100, 200],
                                        'min_samples_leaf' : [1, 5],
                                        'max_depth' : [6, 8, 12]
                                        }
                    },
                    'XGB' : {
                            'model' : XGBClassifier(random_state=RANDOM_STATE),
                            'params' : {
                                        'n_estimators' : [50, 100, 200],                                     
                                        'learning_rate' : [0.05, 0.1],
                                        'max_depth' : [8, 12, 20]
                                        }
                    }
                }

kf = StratifiedKFold(
                n_splits=N_SPLITS,
                shuffle=True, random_state=RANDOM_STATE       
                )

cls_tuning_results = {}
for name, config in param_grids_cls.items():
    print(f"\n Training {name} model...")

#Grid Search Cross Validation
    grid_search = GridSearchCV(
                        estimator=config['model'],
                        param_grid=config['params'],
                        cv=kf, scoring='f1_weighted',
                        verbose=3
                     )
    grid_search.fit(X_train_cls, y_train_cls)

    cls_tuning_results[name] = {
                                'best_params' : grid_search.best_params_,
                                'best_cv_score' : grid_search.best_score_,
                                'best_estimator' : grid_search.best_estimator_
                                }
    
    print(f"    Best Params : {grid_search.best_params_}")
    print(f"    Best Estimators : {grid_search.best_estimator_}")

print("\n classification Tuning Summary")
for name, result in cls_tuning_results.items():
    print(f"    {name} : F1= {result['best_cv_score']:.2f} |  params={result['best_params']}")
# Out:
#  Training RF model...
# Fitting 5 folds for each of 12 candidates, totalling 60 fits
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[11], line 36
#      29 #Grid Search Cross Validation
#      30     grid_search = GridSearchCV(
#      31                         estimator=config['model'],
#      32                         param_grid=config['params'],
#      33                         cv=kf, scoring='f1_weighted',
#      34                         verbose=3
#      35                      )
# ---> 36     grid_search.fit(X_train_cls, y_train_cls)
#      38     cls_tuning_results[name] = {
#      39                                 'best_params' : grid_search.best_params_,
#      40                                 'best_cv_score' : grid_search.best_score_,
#      41                                 'best_estimator' : grid_search.best_estimator_
#      42                                 }
#      44     print(f"    Best Params : {grid_search.best_params_}")
#
# File ~\AppData\Roaming\Python\Python313\site-packages\sklearn\base.py:1365, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1358     estimator._validate_params()
#    1360 with config_context(
#    1361     skip_parameter_validation=(
#    1362         prefer_skip_nested_validation or global_skip_validation
#    1363     )
#    1364 ):
# -> 1365     return fit_method(estimator, *args, **kwargs)
#
# File ~\AppData\Roaming\Python\Python313\site-packages\sklearn\model_selection\_search.py:1051, in BaseSearchCV.fit(self, X, y, **params)
#    1045     results = self._format_results(
#    1046         all_candidate_params, n_splits, all_out, all_more_results
#    1047     )
#    1049     return results
# -> 1051 self._run_search(evaluate_candidates)
#    1053 # multimetric is determined here because in the case of a callable
#    1054 # self.scoring the return type is only known after calling
#    1055 first_test_score = all_out[0]["test_scores"]
#
# File ~\AppData\Roaming\Python\Python313\site-packages\sklearn\model_selection\_search.py:1605, in GridSearchCV._run_search(self, evaluate_candidates)
#    1603 def _run_search(self, evaluate_candidates):
#    1604     """Search all candidates in param_grid"""
# -> 1605     evaluate_candidates(ParameterGrid(self.param_grid))
#
# File ~\AppData\Roaming\Python\Python313\site-packages\sklearn\model_selection\_search.py:997, in BaseSearchCV.fit.<locals>.evaluate_candidates(candidate_params, cv, more_results)
#     989 if self.verbose > 0:
#     990     print(
#     991         "Fitting {0} folds for each of {1} candidates,"
#     992         " totalling {2} fits".format(
#     993             n_splits, n_candidates, n_candidates * n_splits
#     994         )
#     995     )
# --> 997 out = parallel(
#     998     delayed(_fit_and_score)(
#     999         clone(base_estimator),
#    1000         X,
#    1001         y,
#    1002         train=train,
#    1003         test=test,
#    1004         parameters=parameters,
#    1005         split_progress=(split_idx, n_splits),
#    1006         candidate_progress=(cand_idx, n_candidates),
#    1007         **fit_and_score_kwargs,
#    1008     )
#    1009     for (cand_idx, parameters), (split_idx, (train, test)) in product(
#    1010         enumerate(candidate_params),
#    1011         enumerate(cv.split(X, y, **routed_params.splitter.split)),
#    1012     )
#    1013 )
#    1015 if len(out) < 1:
#    1016     raise ValueError(
#    1017         "No fits were performed. "
#    1018         "Was the CV iterator empty? "
#    1019         "Were there no candidates?"
#    1020     )
#
# File ~\AppData\Roaming\Python\Python313\site-packages\sklearn\utils\parallel.py:82, in Parallel.__call__(self, iterable)
#      73 warning_filters = warnings.filters
#      74 iterable_with_config_and_warning_filters = (
#      75     (
#      76         _with_config_and_warning_filters(delayed_func, config, warning_filters),
#    (...)     80     for delayed_func, args, kwargs in iterable
#      81 )
# ---> 82 return super().__call__(iterable_with_config_and_warning_filters)
#
# File ~\AppData\Roaming\Python\Python313\site-packages\joblib\parallel.py:1986, in Parallel.__call__(self, iterable)
#    1984     output = self._get_sequential_output(iterable)
#    1985     next(output)
# -> 1986     return output if self.return_generator else list(output)
#    1988 # Let's create an ID that uniquely identifies the current call. If the
#    1989 # call is interrupted early and that the same instance is immediately
#    1990 # reused, this id will be used to prevent workers that were
#    1991 # concurrently finalizing a task from the previous call to run the
#    1992 # callback.
#    1993 with self._lock:
#
# File ~\AppData\Roaming\Python\Python313\site-packages\joblib\parallel.py:1914, in Parallel._get_sequential_output(self, iterable)
#    1912 self.n_dispatched_batches += 1
#    1913 self.n_dispatched_tasks += 1
# -> 1914 res = func(*args, **kwargs)
#    1915 self.n_completed_tasks += 1
#    1916 self.print_progress()
#
# File ~\AppData\Roaming\Python\Python313\site-packages\sklearn\utils\parallel.py:147, in _FuncWrapper.__call__(self, *args, **kwargs)
#     145 with config_context(**config), warnings.catch_warnings():
#     146     warnings.filters = warning_filters
# --> 147     return self.function(*args, **kwargs)
#
# File ~\AppData\Roaming\Python\Python313\site-packages\sklearn\model_selection\_validation.py:859, in _fit_and_score(estimator, X, y, scorer, train, test, verbose, parameters, fit_params, score_params, return_train_score, return_parameters, return_n_test_samples, return_times, return_estimator, split_progress, candidate_progress, error_score)
#     857         estimator.fit(X_train, **fit_params)
#     858     else:
# --> 859         estimator.fit(X_train, y_train, **fit_params)
#     861 except Exception:
#     862     # Note fit time as time until error
#     863     fit_time = time.time() - start_time
#
# File ~\AppData\Roaming\Python\Python313\site-packages\sklearn\base.py:1365, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1358     estimator._validate_params()
#    1360 with config_context(
#    1361     skip_parameter_validation=(
#    1362         prefer_skip_nested_validation or global_skip_validation
#    1363     )
#    1364 ):
# -> 1365     return fit_method(estimator, *args, **kwargs)
#
# File ~\AppData\Roaming\Python\Python313\site-packages\sklearn\ensemble\_forest.py:486, in BaseForest.fit(self, X, y, sample_weight)
#     475 trees = [
#     476     self._make_estimator(append=False, random_state=random_state)
#     477     for i in range(n_more_estimators)
#     478 ]
#     480 # Parallel loop: we prefer the threading backend as the Cython code
#     481 # for fitting the trees is internally releasing the Python GIL
#     482 # making threading more efficient than multiprocessing in
#     483 # that case. However, for joblib 0.12+ we respect any
#     484 # parallel_backend contexts set at a higher level,
#     485 # since correctness does not rely on using threads.
# --> 486 trees = Parallel(
#     487     n_jobs=self.n_jobs,
#     488     verbose=self.verbose,
#     489     prefer="threads",
#     490 )(
#     491     delayed(_parallel_build_trees)(
#     492         t,
#     493         self.bootstrap,
#     494         X,
#     495         y,
#     496         sample_weight,
#     497         i,
#     498         len(trees),
#     499         verbose=self.verbose,
#     500         class_weight=self.class_weight,
#     501         n_samples_bootstrap=n_samples_bootstrap,
#     502         missing_values_in_feature_mask=missing_values_in_feature_mask,
#     503     )
#     504     for i, t in enumerate(trees)
#     505 )
#     507 # Collect newly grown trees
#     508 self.estimators_.extend(trees)
#
# File ~\AppData\Roaming\Python\Python313\site-packages\sklearn\utils\parallel.py:82, in Parallel.__call__(self, iterable)
#      73 warning_filters = warnings.filters
#      74 iterable_with_config_and_warning_filters = (
#      75     (
#      76         _with_config_and_warning_filters(delayed_func, config, warning_filters),
#    (...)     80     for delayed_func, args, kwargs in iterable
#      81 )
# ---> 82 return super().__call__(iterable_with_config_and_warning_filters)
#
# File ~\AppData\Roaming\Python\Python313\site-packages\joblib\parallel.py:1986, in Parallel.__call__(self, iterable)
#    1984     output = self._get_sequential_output(iterable)
#    1985     next(output)
# -> 1986     return output if self.return_generator else list(output)
#    1988 # Let's create an ID that uniquely identifies the current call. If the
#    1989 # call is interrupted early and that the same instance is immediately
#    1990 # reused, this id will be used to prevent workers that were
#    1991 # concurrently finalizing a task from the previous call to run the
#    1992 # callback.
#    1993 with self._lock:
#
# File ~\AppData\Roaming\Python\Python313\site-packages\joblib\parallel.py:1914, in Parallel._get_sequential_output(self, iterable)
#    1912 self.n_dispatched_batches += 1
#    1913 self.n_dispatched_tasks += 1
# -> 1914 res = func(*args, **kwargs)
#    1915 self.n_completed_tasks += 1
#    1916 self.print_progress()
#
# File ~\AppData\Roaming\Python\Python313\site-packages\sklearn\utils\parallel.py:147, in _FuncWrapper.__call__(self, *args, **kwargs)
#     145 with config_context(**config), warnings.catch_warnings():
#     146     warnings.filters = warning_filters
# --> 147     return self.function(*args, **kwargs)
#
# File ~\AppData\Roaming\Python\Python313\site-packages\sklearn\ensemble\_forest.py:188, in _parallel_build_trees(tree, bootstrap, X, y, sample_weight, tree_idx, n_trees, verbose, class_weight, n_samples_bootstrap, missing_values_in_feature_mask)
#     185     elif class_weight == "balanced_subsample":
#     186         curr_sample_weight *= compute_sample_weight("balanced", y, indices=indices)
# --> 188     tree._fit(
#     189         X,
#     190         y,
#     191         sample_weight=curr_sample_weight,
#     192         check_input=False,
#     193         missing_values_in_feature_mask=missing_values_in_feature_mask,
#     194     )
#     195 else:
#     196     tree._fit(
#     197         X,
#     198         y,
#    (...)    201         missing_values_in_feature_mask=missing_values_in_feature_mask,
#     202     )
#
# File ~\AppData\Roaming\Python\Python313\site-packages\sklearn\tree\_classes.py:472, in BaseDecisionTree._fit(self, X, y, sample_weight, check_input, missing_values_in_feature_mask)
#     461 else:
#     462     builder = BestFirstTreeBuilder(
#     463         splitter,
#     464         min_samples_split,
#    (...)    469         self.min_impurity_decrease,
#     470     )
# --> 472 builder.build(self.tree_, X, y, sample_weight, missing_values_in_feature_mask)
#     474 if self.n_outputs_ == 1 and is_classifier(self):
#     475     self.n_classes_ = self.n_classes_[0]
#
# KeyboardInterrupt:
