# %%
#Imports
import json
import joblib
import warnings
import numpy as np
import pandas as pd
import seaborn as sns
from pathlib import Path
import matplotlib.pyplot as plt
from sklearn.model_selection import GridSearchCV, KFold, StratifiedKFold
from sklearn.metrics import (
                            mean_absolute_error, mean_squared_error, r2_score,
                            accuracy_score, precision_score, recall_score, f1_score, confusion_matrix
                            )
from sklearn.ensemble import RandomForestRegressor, RandomForestClassifier
from xgboost import XGBRegressor, XGBClassifier

warnings.filterwarnings('ignore')
print("Import loaded")
# Out:
# Import loaded

# %%
ARTIFACTS_DIR = Path("artifacts")
FIGURES_DIR = Path("artifacts/figures")
N_SPLITS = 5


RANDOM_STATE = 42
np.random.seed(RANDOM_STATE)

# %% [markdown]
# #### 01) Load Preprocessed Arrays

# %%
X_train_reg = np.load(ARTIFACTS_DIR / 'X_train_reg.npz')['data']
X_test_reg = np.load(ARTIFACTS_DIR / 'X_test_reg.npz')['data']
y_train_reg = np.load(ARTIFACTS_DIR / 'y_train_reg.npz')['data']
y_test_reg = np.load(ARTIFACTS_DIR / 'y_test_reg.npz')['data']

X_train_cls = np.load(ARTIFACTS_DIR / 'X_train_cls.npz')['data']
X_test_cls = np.load(ARTIFACTS_DIR / 'X_test_cls.npz')['data']
y_train_cls = np.load(ARTIFACTS_DIR / 'y_train_cls.npz')['data']
y_test_cls = np.load(ARTIFACTS_DIR / 'y_test_cls.npz')['data']

print("Regression arrays loaded:")
print(f"   X_train : {X_train_reg.shape}, X_test : {X_test_reg.shape}")
print(f"   y_train : {y_train_reg.shape}, y_test : {y_test_reg.shape}")

print("\nClassification arrays loaded:")
print(f"   X_train : {X_train_cls.shape}, X_test : {X_test_cls.shape}")
print(f"   y_train : {y_train_cls.shape}, y_test : {y_test_cls.shape}")
# Out:
# Regression arrays loaded:
#    X_train : (36735, 39), X_test : (9177, 39)
#    y_train : (36735,), y_test : (9177,)
#
# Classification arrays loaded:
#    X_train : (36735, 39), X_test : (9177, 39)
#    y_train : (36735,), y_test : (9177,)

# %%
"""
01. What is KFold ?

|-------------------------------------------------------------------------------|
|       F1      |       F2      |       F3      |       F4      |       F5      |
|-------------------------------------------------------------------------------|

Train - Train the Model
Test- Test model performance
Validation - Hyper Parameter Tuning

F1, F2, F3, F4 - Train, F5 - Validation
F1, F2, F3, F5 - Train, F4 - Validation
F1, F2, F4, F5 - Train, F3 - Validation 
....

02. What is StratifiedKFold ?

This comes in Handy when your dataset is Class Imbalanced ...
Total Sample Count - 16
Two Classses : A & B , A - 12 , B -4
N_SPLITS = 4 (Each split consist of 4)
Kfold the problem is it won't account pproportions. But StratifiedKFold solve this issue.

A : B = 3 : 1

with this everytime it create a split which satisfy A : B


"""
# Out:
# "\n01. What is KFold ?\n\n|-------------------------------------------------------------------------------|\n|       F1      |       F2      |       F3      |       F4      |       F5      |\n|-------------------------------------------------------------------------------|\n\nTrain - Train the Model\nTest- Test model performance\nValidation - Hyper Parameter Tuning\n\nF1, F2, F3, F4 - Train, F5 - Validation\nF1, F2, F3, F5 - Train, F4 - Validation\nF1, F2, F4, F5 - Train, F3 - Validation \n....\n\n02. What is StratifiedKFold ?\n\nThis comes in Handy when your dataset is Class Imbalanced ...\nTotal Sample Count - 16\nTwo Classses : A & B , A - 12 , B -4\nN_SPLITS = 4 (Each split consist of 4)\nKfold the problem is it won't account pproportions. But StratifiedKFold solve this issue.\n\nA : B = 3 : 1\n\nwith this everytime it create a split which satisfy A : B\n\n\n"

# %% [markdown]
# #### 02) Regression Hparam Tuning

# %%
param_grids_regg = {
    
                    'RF' : {
                            'model' : RandomForestRegressor(random_state=RANDOM_STATE),
                            'params' : {
                                        'n_estimators' : [100, 200],
                                        'min_samples_leaf' : [1, 5],
                                        'max_depth' : [6, 8, 12]
                                        }
                    },
                    'XGB' : {
                            'model' : XGBRegressor(random_state=RANDOM_STATE),
                            'params' : {
                                        'n_estimators' : [50, 100, 200],
                                        'learning_rate' : [0.05, 0.1],
                                        'max_depth' : [8, 10, 12]
                                        }
                    }
                }

kf = KFold(
        n_splits=N_SPLITS,
        shuffle=True, random_state=RANDOM_STATE       
        )

reg_tuning_results = {}
for name, config in param_grids_regg.items():
    print(f"\n Training {name} model...")

#Grid Search Cross Validation
    grid_search = GridSearchCV(
                        estimator=config['model'],
                        param_grid=config['params'],
                        cv=kf, scoring='neg_root_mean_squared_error',
                        verbose=3
                     )
    grid_search.fit(X_train_reg, y_train_reg)

    reg_tuning_results[name] = {
                                'best_params' : grid_search.best_params_,
                                'best_cv_score' : grid_search.best_score_,
                                'best_estimator' : grid_search.best_estimator_
                                }
    
    print(f"    Best Params : {grid_search.best_params_}")
    print(f"    Best Estimators : {grid_search.best_estimator_}")

print("\n regression Tuning Summary")
for name, result in reg_tuning_results.items():
    print(f"    {name} : RMSE=${result['best_cv_score']:.2f} |  params={result['best_params']}")
# Out:
#  Training RF model...
# Fitting 5 folds for each of 12 candidates, totalling 60 fits
# [CV 1/5] END max_depth=6, min_samples_leaf=1, n_estimators=100;, score=-45.677 total time=   7.3s
# [CV 2/5] END max_depth=6, min_samples_leaf=1, n_estimators=100;, score=-46.547 total time=   7.3s
# [CV 3/5] END max_depth=6, min_samples_leaf=1, n_estimators=100;, score=-46.037 total time=   7.0s
# [CV 4/5] END max_depth=6, min_samples_leaf=1, n_estimators=100;, score=-45.985 total time=   7.1s
# [CV 5/5] END max_depth=6, min_samples_leaf=1, n_estimators=100;, score=-45.391 total time=   7.8s
# [CV 1/5] END max_depth=6, min_samples_leaf=1, n_estimators=200;, score=-45.673 total time=  12.9s
# [CV 2/5] END max_depth=6, min_samples_leaf=1, n_estimators=200;, score=-46.528 total time=  13.4s
# [CV 3/5] END max_depth=6, min_samples_leaf=1, n_estimators=200;, score=-46.037 total time=  12.2s
# [CV 4/5] END max_depth=6, min_samples_leaf=1, n_estimators=200;, score=-45.989 total time=  12.4s
# [CV 5/5] END max_depth=6, min_samples_leaf=1, n_estimators=200;, score=-45.402 total time=  16.0s
# [CV 1/5] END max_depth=6, min_samples_leaf=5, n_estimators=100;, score=-45.651 total time=   6.5s
# [CV 2/5] END max_depth=6, min_samples_leaf=5, n_estimators=100;, score=-46.519 total time=   5.7s
# [CV 3/5] END max_depth=6, min_samples_leaf=5, n_estimators=100;, score=-46.023 total time=   5.7s
# [CV 4/5] END max_depth=6, min_samples_leaf=5, n_estimators=100;, score=-45.947 total time=   6.2s
# [CV 5/5] END max_depth=6, min_samples_leaf=5, n_estimators=100;, score=-45.371 total time=   5.7s
# [CV 1/5] END max_depth=6, min_samples_leaf=5, n_estimators=200;, score=-45.647 total time=  11.3s
# [CV 2/5] END max_depth=6, min_samples_leaf=5, n_estimators=200;, score=-46.498 total time=  11.8s
# [CV 3/5] END max_depth=6, min_samples_leaf=5, n_estimators=200;, score=-46.018 total time=  12.4s
# [CV 4/5] END max_depth=6, min_samples_leaf=5, n_estimators=200;, score=-45.946 total time=  12.3s
# [CV 5/5] END max_depth=6, min_samples_leaf=5, n_estimators=200;, score=-45.384 total time=  12.1s
# [CV 1/5] END max_depth=8, min_samples_leaf=1, n_estimators=100;, score=-44.836 total time=   7.0s
# [CV 2/5] END max_depth=8, min_samples_leaf=1, n_estimators=100;, score=-45.777 total time=   7.0s
# [CV 3/5] END max_depth=8, min_samples_leaf=1, n_estimators=100;, score=-45.105 total time=   7.2s
# [CV 4/5] END max_depth=8, min_samples_leaf=1, n_estimators=100;, score=-45.145 total time=   7.3s
# [CV 5/5] END max_depth=8, min_samples_leaf=1, n_estimators=100;, score=-44.475 total time=   6.9s
# [CV 1/5] END max_depth=8, min_samples_leaf=1, n_estimators=200;, score=-44.831 total time=  15.9s
# [CV 2/5] END max_depth=8, min_samples_leaf=1, n_estimators=200;, score=-45.749 total time=  16.7s
# [CV 3/5] END max_depth=8, min_samples_leaf=1, n_estimators=200;, score=-45.099 total time=  15.6s
# [CV 4/5] END max_depth=8, min_samples_leaf=1, n_estimators=200;, score=-45.141 total time=  15.4s
# [CV 5/5] END max_depth=8, min_samples_leaf=1, n_estimators=200;, score=-44.470 total time=  15.5s
# [CV 1/5] END max_depth=8, min_samples_leaf=5, n_estimators=100;, score=-44.770 total time=   7.5s
# [CV 2/5] END max_depth=8, min_samples_leaf=5, n_estimators=100;, score=-45.687 total time=   7.5s
# [CV 3/5] END max_depth=8, min_samples_leaf=5, n_estimators=100;, score=-45.076 total time=   7.8s
# [CV 4/5] END max_depth=8, min_samples_leaf=5, n_estimators=100;, score=-45.086 total time=   8.0s
# [CV 5/5] END max_depth=8, min_samples_leaf=5, n_estimators=100;, score=-44.434 total time=   8.6s
# [CV 1/5] END max_depth=8, min_samples_leaf=5, n_estimators=200;, score=-44.768 total time=  14.6s
# [CV 2/5] END max_depth=8, min_samples_leaf=5, n_estimators=200;, score=-45.676 total time=  14.4s
# [CV 3/5] END max_depth=8, min_samples_leaf=5, n_estimators=200;, score=-45.064 total time=  14.4s
# [CV 4/5] END max_depth=8, min_samples_leaf=5, n_estimators=200;, score=-45.093 total time=  14.3s
# [CV 5/5] END max_depth=8, min_samples_leaf=5, n_estimators=200;, score=-44.432 total time=  14.4s
# [CV 1/5] END max_depth=12, min_samples_leaf=1, n_estimators=100;, score=-43.960 total time=  10.3s
# [CV 2/5] END max_depth=12, min_samples_leaf=1, n_estimators=100;, score=-45.019 total time=  10.0s
# [CV 3/5] END max_depth=12, min_samples_leaf=1, n_estimators=100;, score=-44.239 total time=  10.1s
# [CV 4/5] END max_depth=12, min_samples_leaf=1, n_estimators=100;, score=-44.322 total time=  10.2s
# [CV 5/5] END max_depth=12, min_samples_leaf=1, n_estimators=100;, score=-43.705 total time=  10.1s
# [CV 1/5] END max_depth=12, min_samples_leaf=1, n_estimators=200;, score=-43.891 total time=  21.5s
# [CV 2/5] END max_depth=12, min_samples_leaf=1, n_estimators=200;, score=-44.949 total time=  20.6s
# [CV 3/5] END max_depth=12, min_samples_leaf=1, n_estimators=200;, score=-44.199 total time=  20.3s
# [CV 4/5] END max_depth=12, min_samples_leaf=1, n_estimators=200;, score=-44.300 total time=  20.5s
# [CV 5/5] END max_depth=12, min_samples_leaf=1, n_estimators=200;, score=-43.678 total time=  21.9s
# [CV 1/5] END max_depth=12, min_samples_leaf=5, n_estimators=100;, score=-43.796 total time=  10.1s
# [CV 2/5] END max_depth=12, min_samples_leaf=5, n_estimators=100;, score=-44.886 total time=  10.2s
# [CV 3/5] END max_depth=12, min_samples_leaf=5, n_estimators=100;, score=-44.186 total time=   9.5s
# [CV 4/5] END max_depth=12, min_samples_leaf=5, n_estimators=100;, score=-44.186 total time=   9.8s
# [CV 5/5] END max_depth=12, min_samples_leaf=5, n_estimators=100;, score=-43.598 total time=  10.2s
# [CV 1/5] END max_depth=12, min_samples_leaf=5, n_estimators=200;, score=-43.779 total time=  19.7s
# [CV 2/5] END max_depth=12, min_samples_leaf=5, n_estimators=200;, score=-44.850 total time=  19.6s
# [CV 3/5] END max_depth=12, min_samples_leaf=5, n_estimators=200;, score=-44.170 total time=  19.1s
# [CV 4/5] END max_depth=12, min_samples_leaf=5, n_estimators=200;, score=-44.194 total time=  19.0s
# [CV 5/5] END max_depth=12, min_samples_leaf=5, n_estimators=200;, score=-43.589 total time=  20.3s
#     Best Params : {'max_depth': 12, 'min_samples_leaf': 5, 'n_estimators': 200}
#     Best Estimators : RandomForestRegressor(max_depth=12, min_samples_leaf=5, n_estimators=200,
#                       random_state=42)
#
#  Training XGB model...
# Fitting 5 folds for each of 18 candidates, totalling 90 fits
# [CV 1/5] END learning_rate=0.05, max_depth=8, n_estimators=50;, score=-44.204 total time=   2.1s
# [CV 2/5] END learning_rate=0.05, max_depth=8, n_estimators=50;, score=-45.325 total time=   0.2s
# [CV 3/5] END learning_rate=0.05, max_depth=8, n_estimators=50;, score=-44.598 total time=   0.1s
# [CV 4/5] END learning_rate=0.05, max_depth=8, n_estimators=50;, score=-44.761 total time=   0.1s
# [CV 5/5] END learning_rate=0.05, max_depth=8, n_estimators=50;, score=-43.845 total time=   0.1s
# [CV 1/5] END learning_rate=0.05, max_depth=8, n_estimators=100;, score=-43.379 total time=   0.3s
# [CV 2/5] END learning_rate=0.05, max_depth=8, n_estimators=100;, score=-44.721 total time=   0.3s
# [CV 3/5] END learning_rate=0.05, max_depth=8, n_estimators=100;, score=-44.060 total time=   0.3s
# [CV 4/5] END learning_rate=0.05, max_depth=8, n_estimators=100;, score=-44.159 total time=   0.4s
# [CV 5/5] END learning_rate=0.05, max_depth=8, n_estimators=100;, score=-43.299 total time=   0.3s
# [CV 1/5] END learning_rate=0.05, max_depth=8, n_estimators=200;, score=-43.211 total time=   0.6s
# [CV 2/5] END learning_rate=0.05, max_depth=8, n_estimators=200;, score=-44.557 total time=   0.6s
# [CV 3/5] END learning_rate=0.05, max_depth=8, n_estimators=200;, score=-43.937 total time=   0.6s
# [CV 4/5] END learning_rate=0.05, max_depth=8, n_estimators=200;, score=-44.116 total time=   0.7s
# [CV 5/5] END learning_rate=0.05, max_depth=8, n_estimators=200;, score=-43.230 total time=   0.6s
# [CV 1/5] END learning_rate=0.05, max_depth=10, n_estimators=50;, score=-44.074 total time=   0.4s
# [CV 2/5] END learning_rate=0.05, max_depth=10, n_estimators=50;, score=-45.179 total time=   0.4s
# [CV 3/5] END learning_rate=0.05, max_depth=10, n_estimators=50;, score=-44.464 total time=   0.4s
# [CV 4/5] END learning_rate=0.05, max_depth=10, n_estimators=50;, score=-44.563 total time=   0.4s
# [CV 5/5] END learning_rate=0.05, max_depth=10, n_estimators=50;, score=-43.738 total time=   0.4s
# [CV 1/5] END learning_rate=0.05, max_depth=10, n_estimators=100;, score=-43.563 total time=   0.8s
# [CV 2/5] END learning_rate=0.05, max_depth=10, n_estimators=100;, score=-44.882 total time=   0.7s
# [CV 3/5] END learning_rate=0.05, max_depth=10, n_estimators=100;, score=-44.212 total time=   0.7s
# [CV 4/5] END learning_rate=0.05, max_depth=10, n_estimators=100;, score=-44.365 total time=   0.7s
# [CV 5/5] END learning_rate=0.05, max_depth=10, n_estimators=100;, score=-43.540 total time=   0.7s
# [CV 1/5] END learning_rate=0.05, max_depth=10, n_estimators=200;, score=-43.611 total time=   1.2s
# [CV 2/5] END learning_rate=0.05, max_depth=10, n_estimators=200;, score=-44.971 total time=   1.1s
# [CV 3/5] END learning_rate=0.05, max_depth=10, n_estimators=200;, score=-44.376 total time=   1.3s
# [CV 4/5] END learning_rate=0.05, max_depth=10, n_estimators=200;, score=-44.409 total time=   1.2s
# [CV 5/5] END learning_rate=0.05, max_depth=10, n_estimators=200;, score=-43.684 total time=   1.3s
# [CV 1/5] END learning_rate=0.05, max_depth=12, n_estimators=50;, score=-44.301 total time=   1.0s
# [CV 2/5] END learning_rate=0.05, max_depth=12, n_estimators=50;, score=-45.489 total time=   1.0s
# [CV 3/5] END learning_rate=0.05, max_depth=12, n_estimators=50;, score=-44.801 total time=   1.0s
# [CV 4/5] END learning_rate=0.05, max_depth=12, n_estimators=50;, score=-44.777 total time=   0.9s
# [CV 5/5] END learning_rate=0.05, max_depth=12, n_estimators=50;, score=-44.160 total time=   1.0s
# [CV 1/5] END learning_rate=0.05, max_depth=12, n_estimators=100;, score=-44.052 total time=   1.6s
# [CV 2/5] END learning_rate=0.05, max_depth=12, n_estimators=100;, score=-45.542 total time=   1.6s
# [CV 3/5] END learning_rate=0.05, max_depth=12, n_estimators=100;, score=-44.707 total time=   1.6s
# [CV 4/5] END learning_rate=0.05, max_depth=12, n_estimators=100;, score=-44.713 total time=   1.5s
# [CV 5/5] END learning_rate=0.05, max_depth=12, n_estimators=100;, score=-44.225 total time=   2.0s
# [CV 1/5] END learning_rate=0.05, max_depth=12, n_estimators=200;, score=-44.228 total time=   2.7s
# [CV 2/5] END learning_rate=0.05, max_depth=12, n_estimators=200;, score=-45.709 total time=   2.3s
# [CV 3/5] END learning_rate=0.05, max_depth=12, n_estimators=200;, score=-44.888 total time=   2.4s
# [CV 4/5] END learning_rate=0.05, max_depth=12, n_estimators=200;, score=-44.892 total time=   2.2s
# [CV 5/5] END learning_rate=0.05, max_depth=12, n_estimators=200;, score=-44.533 total time=   2.3s
# [CV 1/5] END learning_rate=0.1, max_depth=8, n_estimators=50;, score=-43.272 total time=   0.1s
# [CV 2/5] END learning_rate=0.1, max_depth=8, n_estimators=50;, score=-44.729 total time=   0.1s
# [CV 3/5] END learning_rate=0.1, max_depth=8, n_estimators=50;, score=-43.959 total time=   0.1s
# [CV 4/5] END learning_rate=0.1, max_depth=8, n_estimators=50;, score=-44.240 total time=   0.1s
# [CV 5/5] END learning_rate=0.1, max_depth=8, n_estimators=50;, score=-43.307 total time=   0.1s
# [CV 1/5] END learning_rate=0.1, max_depth=8, n_estimators=100;, score=-43.077 total time=   0.3s
# [CV 2/5] END learning_rate=0.1, max_depth=8, n_estimators=100;, score=-44.645 total time=   0.3s
# [CV 3/5] END learning_rate=0.1, max_depth=8, n_estimators=100;, score=-43.790 total time=   0.2s
# [CV 4/5] END learning_rate=0.1, max_depth=8, n_estimators=100;, score=-44.208 total time=   0.2s
# [CV 5/5] END learning_rate=0.1, max_depth=8, n_estimators=100;, score=-43.308 total time=   0.2s
# [CV 1/5] END learning_rate=0.1, max_depth=8, n_estimators=200;, score=-43.366 total time=   0.5s
# [CV 2/5] END learning_rate=0.1, max_depth=8, n_estimators=200;, score=-44.927 total time=   0.5s
# [CV 3/5] END learning_rate=0.1, max_depth=8, n_estimators=200;, score=-43.893 total time=   0.5s
# [CV 4/5] END learning_rate=0.1, max_depth=8, n_estimators=200;, score=-44.445 total time=   0.5s
# [CV 5/5] END learning_rate=0.1, max_depth=8, n_estimators=200;, score=-43.548 total time=   0.5s
# [CV 1/5] END learning_rate=0.1, max_depth=10, n_estimators=50;, score=-43.674 total time=   0.3s
# [CV 2/5] END learning_rate=0.1, max_depth=10, n_estimators=50;, score=-45.176 total time=   0.3s
# [CV 3/5] END learning_rate=0.1, max_depth=10, n_estimators=50;, score=-44.308 total time=   0.3s
# [CV 4/5] END learning_rate=0.1, max_depth=10, n_estimators=50;, score=-44.350 total time=   0.3s
# [CV 5/5] END learning_rate=0.1, max_depth=10, n_estimators=50;, score=-43.657 total time=   0.3s
# [CV 1/5] END learning_rate=0.1, max_depth=10, n_estimators=100;, score=-43.715 total time=   0.6s
# [CV 2/5] END learning_rate=0.1, max_depth=10, n_estimators=100;, score=-45.277 total time=   0.6s
# [CV 3/5] END learning_rate=0.1, max_depth=10, n_estimators=100;, score=-44.379 total time=   0.6s
# [CV 4/5] END learning_rate=0.1, max_depth=10, n_estimators=100;, score=-44.490 total time=   0.5s
# [CV 5/5] END learning_rate=0.1, max_depth=10, n_estimators=100;, score=-43.866 total time=   0.6s
# [CV 1/5] END learning_rate=0.1, max_depth=10, n_estimators=200;, score=-44.033 total time=   1.0s
# [CV 2/5] END learning_rate=0.1, max_depth=10, n_estimators=200;, score=-45.612 total time=   1.0s
# [CV 3/5] END learning_rate=0.1, max_depth=10, n_estimators=200;, score=-44.744 total time=   1.0s
# [CV 4/5] END learning_rate=0.1, max_depth=10, n_estimators=200;, score=-44.906 total time=   1.0s
# [CV 5/5] END learning_rate=0.1, max_depth=10, n_estimators=200;, score=-44.264 total time=   1.1s
# [CV 1/5] END learning_rate=0.1, max_depth=12, n_estimators=50;, score=-44.166 total time=   0.8s
# [CV 2/5] END learning_rate=0.1, max_depth=12, n_estimators=50;, score=-45.601 total time=   0.8s
# [CV 3/5] END learning_rate=0.1, max_depth=12, n_estimators=50;, score=-44.786 total time=   0.8s
# [CV 4/5] END learning_rate=0.1, max_depth=12, n_estimators=50;, score=-44.828 total time=   0.8s
# [CV 5/5] END learning_rate=0.1, max_depth=12, n_estimators=50;, score=-44.341 total time=   0.7s
# [CV 1/5] END learning_rate=0.1, max_depth=12, n_estimators=100;, score=-44.364 total time=   1.2s
# [CV 2/5] END learning_rate=0.1, max_depth=12, n_estimators=100;, score=-45.798 total time=   1.3s
# [CV 3/5] END learning_rate=0.1, max_depth=12, n_estimators=100;, score=-45.041 total time=   1.3s
# [CV 4/5] END learning_rate=0.1, max_depth=12, n_estimators=100;, score=-45.003 total time=   1.2s
# [CV 5/5] END learning_rate=0.1, max_depth=12, n_estimators=100;, score=-44.672 total time=   1.1s
# [CV 1/5] END learning_rate=0.1, max_depth=12, n_estimators=200;, score=-44.733 total time=   2.0s
# [CV 2/5] END learning_rate=0.1, max_depth=12, n_estimators=200;, score=-46.230 total time=   1.9s
# [CV 3/5] END learning_rate=0.1, max_depth=12, n_estimators=200;, score=-45.425 total time=   2.0s
# [CV 4/5] END learning_rate=0.1, max_depth=12, n_estimators=200;, score=-45.360 total time=   1.9s
# [CV 5/5] END learning_rate=0.1, max_depth=12, n_estimators=200;, score=-45.109 total time=   2.0s
#     Best Params : {'learning_rate': 0.1, 'max_depth': 8, 'n_estimators': 100}
#     Best Estimators : XGBRegressor(base_score=None, booster=None, callbacks=None,
#              colsample_bylevel=None, colsample_bynode=None,
#              colsample_bytree=None, device=None, early_stopping_rounds=None,
#              enable_categorical=False, eval_metric=None, feature_types=None,
#              feature_weights=None, gamma=None, grow_policy=None,
#              importance_type=None, interaction_constraints=None,
#              learning_rate=0.1, max_bin=None, max_cat_threshold=None,
#              max_cat_to_onehot=None, max_delta_step=None, max_depth=8,
#              max_leaves=None, min_child_weight=None, missing=nan,
#              monotone_constraints=None, multi_strategy=None, n_estimators=100,
#              n_jobs=None, num_parallel_tree=None, ...)
#
#  regression Tuning Summary
#     RF : RMSE=$-44.12 |  params={'max_depth': 12, 'min_samples_leaf': 5, 'n_estimators': 200}
#     XGB : RMSE=$-43.81 |  params={'learning_rate': 0.1, 'max_depth': 8, 'n_estimators': 100}

# %% [markdown]
# #### 02) Classification Hparam Tuning

# %%
param_grids_cls = {
                    'RF' : {
                            'model' : RandomForestClassifier(random_state=RANDOM_STATE),
                            'params' : {
                                        'n_estimators' : [100, 200],
                                        'min_samples_leaf' : [1, 5],
                                        'max_depth' : [6, 8, 12]
                                        }
                    },
                    'XGB' : {
                            'model' : XGBClassifier(random_state=RANDOM_STATE),
                            'params' : {
                                        'n_estimators' : [50, 100, 200],                                     
                                        'learning_rate' : [0.05, 0.1],
                                        'max_depth' : [8, 12, 20]
                                        }
                    }
                }

kf = StratifiedKFold(
                n_splits=N_SPLITS,
                shuffle=True, random_state=RANDOM_STATE       
                )

cls_tuning_results = {}
for name, config in param_grids_cls.items():
    print(f"\n Training {name} model...")

#Grid Search Cross Validation
    grid_search = GridSearchCV(
                        estimator=config['model'],
                        param_grid=config['params'],
                        cv=kf, scoring='f1_weighted',
                        verbose=3
                     )
    grid_search.fit(X_train_cls, y_train_cls)

    cls_tuning_results[name] = {
                                'best_params' : grid_search.best_params_,
                                'best_cv_score' : grid_search.best_score_,
                                'best_estimator' : grid_search.best_estimator_
                                }
    
    print(f"    Best Params : {grid_search.best_params_}")
    print(f"    Best Estimators : {grid_search.best_estimator_}")

print("\n classification Tuning Summary")
for name, result in cls_tuning_results.items():
    print(f"    {name} : F1= {result['best_cv_score']:.2f} |  params={result['best_params']}")
# Out:
#  Training RF model...
# Fitting 5 folds for each of 12 candidates, totalling 60 fits
# [CV 1/5] END max_depth=6, min_samples_leaf=1, n_estimators=100;, score=0.668 total time=   1.3s
# [CV 2/5] END max_depth=6, min_samples_leaf=1, n_estimators=100;, score=0.655 total time=   1.3s
# [CV 3/5] END max_depth=6, min_samples_leaf=1, n_estimators=100;, score=0.666 total time=   1.3s
# [CV 4/5] END max_depth=6, min_samples_leaf=1, n_estimators=100;, score=0.673 total time=   1.3s
# [CV 5/5] END max_depth=6, min_samples_leaf=1, n_estimators=100;, score=0.667 total time=   1.4s
# [CV 1/5] END max_depth=6, min_samples_leaf=1, n_estimators=200;, score=0.670 total time=   2.8s
# [CV 2/5] END max_depth=6, min_samples_leaf=1, n_estimators=200;, score=0.655 total time=   2.8s
# [CV 3/5] END max_depth=6, min_samples_leaf=1, n_estimators=200;, score=0.668 total time=   2.7s
# [CV 4/5] END max_depth=6, min_samples_leaf=1, n_estimators=200;, score=0.673 total time=   2.7s
# [CV 5/5] END max_depth=6, min_samples_leaf=1, n_estimators=200;, score=0.668 total time=   3.0s
# [CV 1/5] END max_depth=6, min_samples_leaf=5, n_estimators=100;, score=0.669 total time=   1.5s
# [CV 2/5] END max_depth=6, min_samples_leaf=5, n_estimators=100;, score=0.651 total time=   1.5s
# [CV 3/5] END max_depth=6, min_samples_leaf=5, n_estimators=100;, score=0.666 total time=   1.4s
# [CV 4/5] END max_depth=6, min_samples_leaf=5, n_estimators=100;, score=0.673 total time=   1.5s
# [CV 5/5] END max_depth=6, min_samples_leaf=5, n_estimators=100;, score=0.667 total time=   1.5s
# [CV 1/5] END max_depth=6, min_samples_leaf=5, n_estimators=200;, score=0.667 total time=   3.1s
# [CV 2/5] END max_depth=6, min_samples_leaf=5, n_estimators=200;, score=0.653 total time=   3.2s
# [CV 3/5] END max_depth=6, min_samples_leaf=5, n_estimators=200;, score=0.668 total time=   3.9s
# [CV 4/5] END max_depth=6, min_samples_leaf=5, n_estimators=200;, score=0.672 total time=   3.3s
# [CV 5/5] END max_depth=6, min_samples_leaf=5, n_estimators=200;, score=0.668 total time=   3.2s
# [CV 1/5] END max_depth=8, min_samples_leaf=1, n_estimators=100;, score=0.675 total time=   1.9s
# [CV 2/5] END max_depth=8, min_samples_leaf=1, n_estimators=100;, score=0.663 total time=   1.8s
# [CV 3/5] END max_depth=8, min_samples_leaf=1, n_estimators=100;, score=0.678 total time=   1.8s
# [CV 4/5] END max_depth=8, min_samples_leaf=1, n_estimators=100;, score=0.681 total time=   1.9s
# [CV 5/5] END max_depth=8, min_samples_leaf=1, n_estimators=100;, score=0.680 total time=   1.8s
# [CV 1/5] END max_depth=8, min_samples_leaf=1, n_estimators=200;, score=0.677 total time=   3.9s
# [CV 2/5] END max_depth=8, min_samples_leaf=1, n_estimators=200;, score=0.664 total time=   3.9s
# [CV 3/5] END max_depth=8, min_samples_leaf=1, n_estimators=200;, score=0.677 total time=   3.8s
# [CV 4/5] END max_depth=8, min_samples_leaf=1, n_estimators=200;, score=0.680 total time=   3.7s
# [CV 5/5] END max_depth=8, min_samples_leaf=1, n_estimators=200;, score=0.679 total time=   3.5s
# [CV 1/5] END max_depth=8, min_samples_leaf=5, n_estimators=100;, score=0.675 total time=   2.0s
# [CV 2/5] END max_depth=8, min_samples_leaf=5, n_estimators=100;, score=0.662 total time=   2.0s
# [CV 3/5] END max_depth=8, min_samples_leaf=5, n_estimators=100;, score=0.679 total time=   1.8s
# [CV 4/5] END max_depth=8, min_samples_leaf=5, n_estimators=100;, score=0.678 total time=   1.8s
# [CV 5/5] END max_depth=8, min_samples_leaf=5, n_estimators=100;, score=0.677 total time=   1.8s
# [CV 1/5] END max_depth=8, min_samples_leaf=5, n_estimators=200;, score=0.678 total time=   3.8s
# [CV 2/5] END max_depth=8, min_samples_leaf=5, n_estimators=200;, score=0.664 total time=   3.8s
# [CV 3/5] END max_depth=8, min_samples_leaf=5, n_estimators=200;, score=0.677 total time=   4.0s
# [CV 4/5] END max_depth=8, min_samples_leaf=5, n_estimators=200;, score=0.679 total time=   3.9s
# [CV 5/5] END max_depth=8, min_samples_leaf=5, n_estimators=200;, score=0.677 total time=   3.5s
# [CV 1/5] END max_depth=12, min_samples_leaf=1, n_estimators=100;, score=0.688 total time=   2.4s
# [CV 2/5] END max_depth=12, min_samples_leaf=1, n_estimators=100;, score=0.676 total time=   2.2s
# [CV 3/5] END max_depth=12, min_samples_leaf=1, n_estimators=100;, score=0.690 total time=   2.2s
# [CV 4/5] END max_depth=12, min_samples_leaf=1, n_estimators=100;, score=0.695 total time=   2.2s
# [CV 5/5] END max_depth=12, min_samples_leaf=1, n_estimators=100;, score=0.695 total time=   2.6s
# [CV 1/5] END max_depth=12, min_samples_leaf=1, n_estimators=200;, score=0.689 total time=   5.2s
# [CV 2/5] END max_depth=12, min_samples_leaf=1, n_estimators=200;, score=0.675 total time=   5.2s
# [CV 3/5] END max_depth=12, min_samples_leaf=1, n_estimators=200;, score=0.689 total time=   4.9s
# [CV 4/5] END max_depth=12, min_samples_leaf=1, n_estimators=200;, score=0.693 total time=   4.7s
# [CV 5/5] END max_depth=12, min_samples_leaf=1, n_estimators=200;, score=0.695 total time=   4.7s
# [CV 1/5] END max_depth=12, min_samples_leaf=5, n_estimators=100;, score=0.686 total time=   2.2s
# [CV 2/5] END max_depth=12, min_samples_leaf=5, n_estimators=100;, score=0.675 total time=   2.3s
# [CV 3/5] END max_depth=12, min_samples_leaf=5, n_estimators=100;, score=0.688 total time=   2.6s
# [CV 4/5] END max_depth=12, min_samples_leaf=5, n_estimators=100;, score=0.691 total time=   2.3s
# [CV 5/5] END max_depth=12, min_samples_leaf=5, n_estimators=100;, score=0.692 total time=   2.4s
# [CV 1/5] END max_depth=12, min_samples_leaf=5, n_estimators=200;, score=0.687 total time=   4.8s
# [CV 2/5] END max_depth=12, min_samples_leaf=5, n_estimators=200;, score=0.676 total time=   4.7s
# [CV 3/5] END max_depth=12, min_samples_leaf=5, n_estimators=200;, score=0.686 total time=   5.4s
# [CV 4/5] END max_depth=12, min_samples_leaf=5, n_estimators=200;, score=0.691 total time=   5.2s
# [CV 5/5] END max_depth=12, min_samples_leaf=5, n_estimators=200;, score=0.693 total time=   4.9s
#     Best Params : {'max_depth': 12, 'min_samples_leaf': 1, 'n_estimators': 100}
#     Best Estimators : RandomForestClassifier(max_depth=12, random_state=42)
#
#  Training XGB model...
# Fitting 5 folds for each of 18 candidates, totalling 90 fits
# [CV 1/5] END learning_rate=0.05, max_depth=8, n_estimators=50;, score=0.681 total time=   0.5s
# [CV 2/5] END learning_rate=0.05, max_depth=8, n_estimators=50;, score=0.673 total time=   0.5s
# [CV 3/5] END learning_rate=0.05, max_depth=8, n_estimators=50;, score=0.684 total time=   0.4s
# [CV 4/5] END learning_rate=0.05, max_depth=8, n_estimators=50;, score=0.687 total time=   0.4s
# [CV 5/5] END learning_rate=0.05, max_depth=8, n_estimators=50;, score=0.689 total time=   0.5s
# [CV 1/5] END learning_rate=0.05, max_depth=8, n_estimators=100;, score=0.686 total time=   0.9s
# [CV 2/5] END learning_rate=0.05, max_depth=8, n_estimators=100;, score=0.681 total time=   0.7s
# [CV 3/5] END learning_rate=0.05, max_depth=8, n_estimators=100;, score=0.693 total time=   0.7s
# [CV 4/5] END learning_rate=0.05, max_depth=8, n_estimators=100;, score=0.695 total time=   0.8s
# [CV 5/5] END learning_rate=0.05, max_depth=8, n_estimators=100;, score=0.698 total time=   0.8s
# [CV 1/5] END learning_rate=0.05, max_depth=8, n_estimators=200;, score=0.686 total time=   1.6s
# [CV 2/5] END learning_rate=0.05, max_depth=8, n_estimators=200;, score=0.684 total time=   1.5s
# [CV 3/5] END learning_rate=0.05, max_depth=8, n_estimators=200;, score=0.699 total time=   1.4s
# [CV 4/5] END learning_rate=0.05, max_depth=8, n_estimators=200;, score=0.704 total time=   1.3s
# [CV 5/5] END learning_rate=0.05, max_depth=8, n_estimators=200;, score=0.695 total time=   1.2s
# [CV 1/5] END learning_rate=0.05, max_depth=12, n_estimators=50;, score=0.685 total time=   1.2s
# [CV 2/5] END learning_rate=0.05, max_depth=12, n_estimators=50;, score=0.683 total time=   1.3s
# [CV 3/5] END learning_rate=0.05, max_depth=12, n_estimators=50;, score=0.696 total time=   1.2s
# [CV 4/5] END learning_rate=0.05, max_depth=12, n_estimators=50;, score=0.691 total time=   1.5s
# [CV 5/5] END learning_rate=0.05, max_depth=12, n_estimators=50;, score=0.694 total time=   1.2s
# [CV 1/5] END learning_rate=0.05, max_depth=12, n_estimators=100;, score=0.688 total time=   2.2s
# [CV 2/5] END learning_rate=0.05, max_depth=12, n_estimators=100;, score=0.687 total time=   2.4s
# [CV 3/5] END learning_rate=0.05, max_depth=12, n_estimators=100;, score=0.697 total time=   2.3s
# [CV 4/5] END learning_rate=0.05, max_depth=12, n_estimators=100;, score=0.696 total time=   2.3s
# [CV 5/5] END learning_rate=0.05, max_depth=12, n_estimators=100;, score=0.694 total time=   2.4s
# [CV 1/5] END learning_rate=0.05, max_depth=12, n_estimators=200;, score=0.685 total time=   4.2s
# [CV 2/5] END learning_rate=0.05, max_depth=12, n_estimators=200;, score=0.686 total time=   4.8s
# [CV 3/5] END learning_rate=0.05, max_depth=12, n_estimators=200;, score=0.696 total time=   4.3s
# [CV 4/5] END learning_rate=0.05, max_depth=12, n_estimators=200;, score=0.695 total time=   4.1s
# [CV 5/5] END learning_rate=0.05, max_depth=12, n_estimators=200;, score=0.693 total time=   4.2s
# [CV 1/5] END learning_rate=0.05, max_depth=20, n_estimators=50;, score=0.679 total time=   6.9s
# [CV 2/5] END learning_rate=0.05, max_depth=20, n_estimators=50;, score=0.676 total time=   6.8s
# [CV 3/5] END learning_rate=0.05, max_depth=20, n_estimators=50;, score=0.678 total time=   6.6s
# [CV 4/5] END learning_rate=0.05, max_depth=20, n_estimators=50;, score=0.685 total time=   5.5s
# [CV 5/5] END learning_rate=0.05, max_depth=20, n_estimators=50;, score=0.687 total time=   5.2s
# [CV 1/5] END learning_rate=0.05, max_depth=20, n_estimators=100;, score=0.681 total time=   8.4s
# [CV 2/5] END learning_rate=0.05, max_depth=20, n_estimators=100;, score=0.678 total time=   7.7s
# [CV 3/5] END learning_rate=0.05, max_depth=20, n_estimators=100;, score=0.679 total time=   7.7s
# [CV 4/5] END learning_rate=0.05, max_depth=20, n_estimators=100;, score=0.687 total time=   8.1s
# [CV 5/5] END learning_rate=0.05, max_depth=20, n_estimators=100;, score=0.690 total time=   8.2s
# [CV 1/5] END learning_rate=0.05, max_depth=20, n_estimators=200;, score=0.679 total time=   9.7s
# [CV 2/5] END learning_rate=0.05, max_depth=20, n_estimators=200;, score=0.678 total time=  12.0s
# [CV 3/5] END learning_rate=0.05, max_depth=20, n_estimators=200;, score=0.681 total time=  13.2s
# [CV 4/5] END learning_rate=0.05, max_depth=20, n_estimators=200;, score=0.688 total time=  10.5s
# [CV 5/5] END learning_rate=0.05, max_depth=20, n_estimators=200;, score=0.687 total time=  13.8s
# [CV 1/5] END learning_rate=0.1, max_depth=8, n_estimators=50;, score=0.690 total time=   0.4s
# [CV 2/5] END learning_rate=0.1, max_depth=8, n_estimators=50;, score=0.686 total time=   0.3s
# [CV 3/5] END learning_rate=0.1, max_depth=8, n_estimators=50;, score=0.694 total time=   0.4s
# [CV 4/5] END learning_rate=0.1, max_depth=8, n_estimators=50;, score=0.695 total time=   0.3s
# [CV 5/5] END learning_rate=0.1, max_depth=8, n_estimators=50;, score=0.698 total time=   0.3s
# [CV 1/5] END learning_rate=0.1, max_depth=8, n_estimators=100;, score=0.689 total time=   0.7s
# [CV 2/5] END learning_rate=0.1, max_depth=8, n_estimators=100;, score=0.687 total time=   0.8s
# [CV 3/5] END learning_rate=0.1, max_depth=8, n_estimators=100;, score=0.697 total time=   0.7s
# [CV 4/5] END learning_rate=0.1, max_depth=8, n_estimators=100;, score=0.699 total time=   0.6s
# [CV 5/5] END learning_rate=0.1, max_depth=8, n_estimators=100;, score=0.697 total time=   0.7s
# [CV 1/5] END learning_rate=0.1, max_depth=8, n_estimators=200;, score=0.688 total time=   1.3s
# [CV 2/5] END learning_rate=0.1, max_depth=8, n_estimators=200;, score=0.687 total time=   1.3s
# [CV 3/5] END learning_rate=0.1, max_depth=8, n_estimators=200;, score=0.700 total time=   1.3s
# [CV 4/5] END learning_rate=0.1, max_depth=8, n_estimators=200;, score=0.698 total time=   1.5s
# [CV 5/5] END learning_rate=0.1, max_depth=8, n_estimators=200;, score=0.697 total time=   1.4s
# [CV 1/5] END learning_rate=0.1, max_depth=12, n_estimators=50;, score=0.688 total time=   1.1s
# [CV 2/5] END learning_rate=0.1, max_depth=12, n_estimators=50;, score=0.687 total time=   1.2s
# [CV 3/5] END learning_rate=0.1, max_depth=12, n_estimators=50;, score=0.693 total time=   1.3s
# [CV 4/5] END learning_rate=0.1, max_depth=12, n_estimators=50;, score=0.697 total time=   1.2s
# [CV 5/5] END learning_rate=0.1, max_depth=12, n_estimators=50;, score=0.693 total time=   1.3s
# [CV 1/5] END learning_rate=0.1, max_depth=12, n_estimators=100;, score=0.686 total time=   2.2s
# [CV 2/5] END learning_rate=0.1, max_depth=12, n_estimators=100;, score=0.685 total time=   2.2s
# [CV 3/5] END learning_rate=0.1, max_depth=12, n_estimators=100;, score=0.693 total time=   5.8s
# [CV 4/5] END learning_rate=0.1, max_depth=12, n_estimators=100;, score=0.697 total time=   3.6s
# [CV 5/5] END learning_rate=0.1, max_depth=12, n_estimators=100;, score=0.695 total time=   2.0s
# [CV 1/5] END learning_rate=0.1, max_depth=12, n_estimators=200;, score=0.685 total time=   3.5s
# [CV 2/5] END learning_rate=0.1, max_depth=12, n_estimators=200;, score=0.684 total time=   3.1s
# [CV 3/5] END learning_rate=0.1, max_depth=12, n_estimators=200;, score=0.686 total time=   3.2s
# [CV 4/5] END learning_rate=0.1, max_depth=12, n_estimators=200;, score=0.690 total time=   5.4s
# [CV 5/5] END learning_rate=0.1, max_depth=12, n_estimators=200;, score=0.698 total time=   3.9s
# [CV 1/5] END learning_rate=0.1, max_depth=20, n_estimators=50;, score=0.679 total time=   4.1s
# [CV 2/5] END learning_rate=0.1, max_depth=20, n_estimators=50;, score=0.678 total time=   3.7s
# [CV 3/5] END learning_rate=0.1, max_depth=20, n_estimators=50;, score=0.682 total time=   4.3s
# [CV 4/5] END learning_rate=0.1, max_depth=20, n_estimators=50;, score=0.688 total time=   4.2s
# [CV 5/5] END learning_rate=0.1, max_depth=20, n_estimators=50;, score=0.686 total time=   4.3s
# [CV 1/5] END learning_rate=0.1, max_depth=20, n_estimators=100;, score=0.681 total time=   6.4s
# [CV 2/5] END learning_rate=0.1, max_depth=20, n_estimators=100;, score=0.679 total time=   7.0s
# [CV 3/5] END learning_rate=0.1, max_depth=20, n_estimators=100;, score=0.684 total time=   6.6s
# [CV 4/5] END learning_rate=0.1, max_depth=20, n_estimators=100;, score=0.688 total time=   5.7s
# [CV 5/5] END learning_rate=0.1, max_depth=20, n_estimators=100;, score=0.689 total time=   5.8s
# [CV 1/5] END learning_rate=0.1, max_depth=20, n_estimators=200;, score=0.679 total time=   9.1s
# [CV 2/5] END learning_rate=0.1, max_depth=20, n_estimators=200;, score=0.677 total time=   9.1s
# [CV 3/5] END learning_rate=0.1, max_depth=20, n_estimators=200;, score=0.683 total time=   9.5s
# [CV 4/5] END learning_rate=0.1, max_depth=20, n_estimators=200;, score=0.687 total time=   9.4s
# [CV 5/5] END learning_rate=0.1, max_depth=20, n_estimators=200;, score=0.689 total time=  10.0s
#     Best Params : {'learning_rate': 0.1, 'max_depth': 8, 'n_estimators': 200}
#     Best Estimators : XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, device=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric=None, feature_types=None,
#               feature_weights=None, gamma=None, grow_policy=None,
#               importance_type=None, interaction_constraints=None,
#               learning_rate=0.1, max_bin=None, max_cat_threshold=None,
#               max_cat_to_onehot=None, max_delta_step=None, max_depth=8,
#               max_leaves=None, min_child_weight=None, missing=nan,
#               monotone_constraints=None, multi_strategy=None, n_estimators=200,
#               n_jobs=None, num_parallel_tree=None, ...)
#
#  classification Tuning Summary
#     RF : F1= 0.69 |  params={'max_depth': 12, 'min_samples_leaf': 1, 'n_estimators': 100}
#     XGB : F1= 0.69 |  params={'learning_rate': 0.1, 'max_depth': 8, 'n_estimators': 200}
