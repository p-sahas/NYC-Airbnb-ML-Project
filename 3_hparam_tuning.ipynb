# %%
#Imports
import json
import joblib
import warnings
import numpy as np
import pandas as pd
import seaborn as sns
from pathlib import Path
import matplotlib.pyplot as plt
from sklearn.model_selection import GridSearchCV, KFold, StratifiedKFold
from sklearn.metrics import (
                            mean_absolute_error, mean_squared_error, r2_score,
                            accuracy_score, precision_score, recall_score, f1_score, confusion_matrix
                            )
from sklearn.ensemble import RandomForestRegressor, RandomForestClassifier
from xgboost import XGBRegressor, XGBClassifier

warnings.filterwarnings('ignore')
print("Import loaded")
# Out:
# Import loaded

# %%
ARTIFACTS_DIR = Path("artifacts")
FIGURES_DIR = Path("artifacts/figures")
N_SPLITS = 5


RANDOM_STATE = 42
np.random.seed(RANDOM_STATE)

# %% [markdown]
# #### 01) Load Preprocessed Arrays

# %%
X_train_reg = np.load(ARTIFACTS_DIR / 'X_train_reg.npz')['data']
X_test_reg = np.load(ARTIFACTS_DIR / 'X_test_reg.npz')['data']
y_train_reg = np.load(ARTIFACTS_DIR / 'y_train_reg.npz')['data']
y_test_reg = np.load(ARTIFACTS_DIR / 'y_test_reg.npz')['data']

X_train_cls = np.load(ARTIFACTS_DIR / 'X_train_cls.npz')['data']
X_test_cls = np.load(ARTIFACTS_DIR / 'X_test_cls.npz')['data']
y_train_cls = np.load(ARTIFACTS_DIR / 'y_train_cls.npz')['data']
y_test_cls = np.load(ARTIFACTS_DIR / 'y_test_cls.npz')['data']

print("Regression arrays loaded:")
print(f"   X_train : {X_train_reg.shape}, X_test : {X_test_reg.shape}")
print(f"   y_train : {y_train_reg.shape}, y_test : {y_test_reg.shape}")

print("\nClassification arrays loaded:")
print(f"   X_train : {X_train_cls.shape}, X_test : {X_test_cls.shape}")
print(f"   y_train : {y_train_cls.shape}, y_test : {y_test_cls.shape}")
# Out:
# Regression arrays loaded:
#    X_train : (36735, 39), X_test : (9177, 39)
#    y_train : (36735,), y_test : (9177,)
#
# Classification arrays loaded:
#    X_train : (36735, 39), X_test : (9177, 39)
#    y_train : (36735,), y_test : (9177,)

# %%
"""
01. What is KFold ?

|-------------------------------------------------------------------------------|
|       F1      |       F2      |       F3      |       F4      |       F5      |
|-------------------------------------------------------------------------------|

Train - Train the Model
Test- Test model performance
Validation - Hyper Parameter Tuning

F1, F2, F3, F4 - Train, F5 - Validation
F1, F2, F3, F5 - Train, F4 - Validation
F1, F2, F4, F5 - Train, F3 - Validation 
....

02. What is StratifiedKFold ?

This comes in Handy when your dataset is Class Imbalanced ...
Total Sample Count - 16
Two Classses : A & B , A - 12 , B -4
N_SPLITS = 4 (Each split consist of 4)
Kfold the problem is it won't account pproportions. But StratifiedKFold solve this issue.

A : B = 3 : 1

with this everytime it create a split which satisfy A : B


"""
# Out:
# "\n01. What is KFold ?\n\n|-------------------------------------------------------------------------------|\n|       F1      |       F2      |       F3      |       F4      |       F5      |\n|-------------------------------------------------------------------------------|\n\nTrain - Train the Model\nTest- Test model performance\nValidation - Hyper Parameter Tuning\n\nF1, F2, F3, F4 - Train, F5 - Validation\nF1, F2, F3, F5 - Train, F4 - Validation\nF1, F2, F4, F5 - Train, F3 - Validation \n....\n\n02. What is StratifiedKFold ?\n\nThis comes in Handy when your dataset is Class Imbalanced ...\nTotal Sample Count - 16\nTwo Classses : A & B , A - 12 , B -4\nN_SPLITS = 4 (Each split consist of 4)\nKfold the problem is it won't account pproportions. But StratifiedKFold solve this issue.\n\nA : B = 3 : 1\n\nwith this everytime it create a split which satisfy A : B\n\n\n"

# %% [markdown]
# #### 02) Regression Hparam Tuning

# %%
param_grids_regg = {
    
                    'RF' : {
                            'model' : RandomForestRegressor(random_state=RANDOM_STATE),
                            'params' : {
                                        'n_estimators' : [100, 200],
                                        'min_samples_leaf' : [1, 5],
                                        'max_depth' : [6, 8, 12]
                                        }
                    },
                    'XGB' : {
                            'model' : XGBRegressor(random_state=RANDOM_STATE),
                            'params' : {
                                        'n_estimators' : [50, 100, 200],
                                        'min_samples_leaf' : [0.05, 0.1],
                                        'max_depth' : [6, 12, 28]
                                        }
                    }
                }

kf = KFold(
        n_splits=N_SPLITS,
        shuffle=True, random_state=RANDOM_STATE       
        )

reg_tuning_results = {}
for name, config in param_grids_regg.items():
    print(f"\n Training {name} model...")

#Grid Search Cross Validation
    grid_search = GridSearchCV(
                        estimator=config['model'],
                        param_grid=config['params'],
                        cv=kf, scoring='neg_root_mean_squared_error',
                        verbose=3
                     )
    grid_search.fit(X_train_reg, y_train_reg)

    reg_tuning_results[name] = {
                                'best_params' : grid_search.best_params_,
                                'best_cv_score' : grid_search.best_score_,
                                'best_estimator' : grid_search.best_estimator_
                                }
    
    print(f"    Best Params : {grid_search.best_params_}")
    print(f"    Best Estimators : {grid_search.best_estimator_}")

print("\n regression Tuning Summary")
for name, result in reg_tuning_results.items():
    print(f"    {name} : RMSE=${result['best_cv_score']:.2f} |  params={result['best_params']}")
# Out:
#  Training RF model...
# Fitting 5 folds for each of 12 candidates, totalling 60 fits
# [CV 1/5] END max_depth=6, min_samples_leaf=1, n_estimators=100;, score=-45.677 total time=   5.9s
# [CV 2/5] END max_depth=6, min_samples_leaf=1, n_estimators=100;, score=-46.547 total time=   5.9s
# [CV 3/5] END max_depth=6, min_samples_leaf=1, n_estimators=100;, score=-46.037 total time=   5.8s
# [CV 4/5] END max_depth=6, min_samples_leaf=1, n_estimators=100;, score=-45.985 total time=   5.8s
# [CV 5/5] END max_depth=6, min_samples_leaf=1, n_estimators=100;, score=-45.391 total time=   5.8s
# [CV 1/5] END max_depth=6, min_samples_leaf=1, n_estimators=200;, score=-45.673 total time=  11.9s
# [CV 2/5] END max_depth=6, min_samples_leaf=1, n_estimators=200;, score=-46.528 total time=  11.6s
# [CV 3/5] END max_depth=6, min_samples_leaf=1, n_estimators=200;, score=-46.037 total time=  11.5s
# [CV 4/5] END max_depth=6, min_samples_leaf=1, n_estimators=200;, score=-45.989 total time=  11.5s
# [CV 5/5] END max_depth=6, min_samples_leaf=1, n_estimators=200;, score=-45.402 total time=  11.4s
# [CV 1/5] END max_depth=6, min_samples_leaf=5, n_estimators=100;, score=-45.651 total time=   5.9s
# [CV 2/5] END max_depth=6, min_samples_leaf=5, n_estimators=100;, score=-46.519 total time=   6.2s
# [CV 3/5] END max_depth=6, min_samples_leaf=5, n_estimators=100;, score=-46.023 total time=   6.2s
# [CV 4/5] END max_depth=6, min_samples_leaf=5, n_estimators=100;, score=-45.947 total time=   6.0s
# [CV 5/5] END max_depth=6, min_samples_leaf=5, n_estimators=100;, score=-45.371 total time=   6.1s
# [CV 1/5] END max_depth=6, min_samples_leaf=5, n_estimators=200;, score=-45.647 total time=  12.1s
# [CV 2/5] END max_depth=6, min_samples_leaf=5, n_estimators=200;, score=-46.498 total time=  11.9s
# [CV 3/5] END max_depth=6, min_samples_leaf=5, n_estimators=200;, score=-46.018 total time=  11.7s
# [CV 4/5] END max_depth=6, min_samples_leaf=5, n_estimators=200;, score=-45.946 total time=  12.4s
# [CV 5/5] END max_depth=6, min_samples_leaf=5, n_estimators=200;, score=-45.384 total time=  12.3s
# [CV 1/5] END max_depth=8, min_samples_leaf=1, n_estimators=100;, score=-44.836 total time=   7.4s
# [CV 2/5] END max_depth=8, min_samples_leaf=1, n_estimators=100;, score=-45.777 total time=   7.3s
# [CV 3/5] END max_depth=8, min_samples_leaf=1, n_estimators=100;, score=-45.105 total time=   7.4s
# [CV 4/5] END max_depth=8, min_samples_leaf=1, n_estimators=100;, score=-45.145 total time=   8.0s
# [CV 5/5] END max_depth=8, min_samples_leaf=1, n_estimators=100;, score=-44.475 total time=   7.5s
# [CV 1/5] END max_depth=8, min_samples_leaf=1, n_estimators=200;, score=-44.831 total time=  15.3s
# [CV 2/5] END max_depth=8, min_samples_leaf=1, n_estimators=200;, score=-45.749 total time=  14.8s
# [CV 3/5] END max_depth=8, min_samples_leaf=1, n_estimators=200;, score=-45.099 total time=  14.2s
# [CV 4/5] END max_depth=8, min_samples_leaf=1, n_estimators=200;, score=-45.141 total time=  14.9s
# [CV 5/5] END max_depth=8, min_samples_leaf=1, n_estimators=200;, score=-44.470 total time=  14.3s
# [CV 1/5] END max_depth=8, min_samples_leaf=5, n_estimators=100;, score=-44.770 total time=   7.8s
# [CV 2/5] END max_depth=8, min_samples_leaf=5, n_estimators=100;, score=-45.687 total time=   8.0s
# [CV 3/5] END max_depth=8, min_samples_leaf=5, n_estimators=100;, score=-45.076 total time=   7.9s
# [CV 4/5] END max_depth=8, min_samples_leaf=5, n_estimators=100;, score=-45.086 total time=   7.6s
# [CV 5/5] END max_depth=8, min_samples_leaf=5, n_estimators=100;, score=-44.434 total time=   7.6s
# [CV 1/5] END max_depth=8, min_samples_leaf=5, n_estimators=200;, score=-44.768 total time=  15.7s
# [CV 2/5] END max_depth=8, min_samples_leaf=5, n_estimators=200;, score=-45.676 total time=  15.5s
# [CV 3/5] END max_depth=8, min_samples_leaf=5, n_estimators=200;, score=-45.064 total time=  14.9s
# [CV 4/5] END max_depth=8, min_samples_leaf=5, n_estimators=200;, score=-45.093 total time=  15.4s
# [CV 5/5] END max_depth=8, min_samples_leaf=5, n_estimators=200;, score=-44.432 total time=  14.6s
# [CV 1/5] END max_depth=12, min_samples_leaf=1, n_estimators=100;, score=-43.960 total time=  10.3s
# [CV 2/5] END max_depth=12, min_samples_leaf=1, n_estimators=100;, score=-45.019 total time=  10.4s
# [CV 3/5] END max_depth=12, min_samples_leaf=1, n_estimators=100;, score=-44.239 total time=  10.4s
# [CV 4/5] END max_depth=12, min_samples_leaf=1, n_estimators=100;, score=-44.322 total time=  10.4s
# [CV 5/5] END max_depth=12, min_samples_leaf=1, n_estimators=100;, score=-43.705 total time=  10.2s
# [CV 1/5] END max_depth=12, min_samples_leaf=1, n_estimators=200;, score=-43.891 total time=  20.5s
# [CV 2/5] END max_depth=12, min_samples_leaf=1, n_estimators=200;, score=-44.949 total time=  20.9s
# [CV 3/5] END max_depth=12, min_samples_leaf=1, n_estimators=200;, score=-44.199 total time=  21.3s
# [CV 4/5] END max_depth=12, min_samples_leaf=1, n_estimators=200;, score=-44.300 total time=  20.7s
# [CV 5/5] END max_depth=12, min_samples_leaf=1, n_estimators=200;, score=-43.678 total time=  21.3s
# [CV 1/5] END max_depth=12, min_samples_leaf=5, n_estimators=100;, score=-43.796 total time=   9.8s
# [CV 2/5] END max_depth=12, min_samples_leaf=5, n_estimators=100;, score=-44.886 total time=  10.0s
# [CV 3/5] END max_depth=12, min_samples_leaf=5, n_estimators=100;, score=-44.186 total time=  10.5s
# [CV 4/5] END max_depth=12, min_samples_leaf=5, n_estimators=100;, score=-44.186 total time=   9.9s
# [CV 5/5] END max_depth=12, min_samples_leaf=5, n_estimators=100;, score=-43.598 total time=   9.7s
# [CV 1/5] END max_depth=12, min_samples_leaf=5, n_estimators=200;, score=-43.779 total time=  19.5s
# [CV 2/5] END max_depth=12, min_samples_leaf=5, n_estimators=200;, score=-44.850 total time=  19.3s
# [CV 3/5] END max_depth=12, min_samples_leaf=5, n_estimators=200;, score=-44.170 total time=  19.5s
# [CV 4/5] END max_depth=12, min_samples_leaf=5, n_estimators=200;, score=-44.194 total time=  19.4s
# [CV 5/5] END max_depth=12, min_samples_leaf=5, n_estimators=200;, score=-43.589 total time=  19.4s
#     Best Params : {'max_depth': 12, 'min_samples_leaf': 5, 'n_estimators': 200}
#     Best Estimators : RandomForestRegressor(max_depth=12, min_samples_leaf=5, n_estimators=200,
#                       random_state=42)
#
#  Training XGB model...
# Fitting 5 folds for each of 18 candidates, totalling 90 fits
# [CV 1/5] END max_depth=6, min_samples_leaf=0.05, n_estimators=50;, score=-43.735 total time=   0.0s
# [CV 2/5] END max_depth=6, min_samples_leaf=0.05, n_estimators=50;, score=-44.740 total time=   0.0s
# [CV 3/5] END max_depth=6, min_samples_leaf=0.05, n_estimators=50;, score=-44.135 total time=   0.0s
# [CV 4/5] END max_depth=6, min_samples_leaf=0.05, n_estimators=50;, score=-44.562 total time=   0.0s
# [CV 5/5] END max_depth=6, min_samples_leaf=0.05, n_estimators=50;, score=-43.684 total time=   0.0s
# [CV 1/5] END max_depth=6, min_samples_leaf=0.05, n_estimators=100;, score=-43.906 total time=   0.0s
# [CV 2/5] END max_depth=6, min_samples_leaf=0.05, n_estimators=100;, score=-45.021 total time=   0.1s
# [CV 3/5] END max_depth=6, min_samples_leaf=0.05, n_estimators=100;, score=-44.329 total time=   0.1s
# [CV 4/5] END max_depth=6, min_samples_leaf=0.05, n_estimators=100;, score=-44.864 total time=   0.1s
# [CV 5/5] END max_depth=6, min_samples_leaf=0.05, n_estimators=100;, score=-44.147 total time=   0.0s
# [CV 1/5] END max_depth=6, min_samples_leaf=0.05, n_estimators=200;, score=-44.448 total time=   0.2s
# [CV 2/5] END max_depth=6, min_samples_leaf=0.05, n_estimators=200;, score=-45.743 total time=   0.2s
# [CV 3/5] END max_depth=6, min_samples_leaf=0.05, n_estimators=200;, score=-44.829 total time=   0.2s
# [CV 4/5] END max_depth=6, min_samples_leaf=0.05, n_estimators=200;, score=-45.561 total time=   0.2s
# [CV 5/5] END max_depth=6, min_samples_leaf=0.05, n_estimators=200;, score=-44.660 total time=   0.2s
# [CV 1/5] END max_depth=6, min_samples_leaf=0.1, n_estimators=50;, score=-43.735 total time=   0.0s
# [CV 2/5] END max_depth=6, min_samples_leaf=0.1, n_estimators=50;, score=-44.740 total time=   0.0s
# [CV 3/5] END max_depth=6, min_samples_leaf=0.1, n_estimators=50;, score=-44.135 total time=   0.0s
# [CV 4/5] END max_depth=6, min_samples_leaf=0.1, n_estimators=50;, score=-44.562 total time=   0.0s
# [CV 5/5] END max_depth=6, min_samples_leaf=0.1, n_estimators=50;, score=-43.684 total time=   0.0s
# [CV 1/5] END max_depth=6, min_samples_leaf=0.1, n_estimators=100;, score=-43.906 total time=   0.1s
# [CV 2/5] END max_depth=6, min_samples_leaf=0.1, n_estimators=100;, score=-45.021 total time=   0.2s
# [CV 3/5] END max_depth=6, min_samples_leaf=0.1, n_estimators=100;, score=-44.329 total time=   0.2s
# [CV 4/5] END max_depth=6, min_samples_leaf=0.1, n_estimators=100;, score=-44.864 total time=   0.3s
# [CV 5/5] END max_depth=6, min_samples_leaf=0.1, n_estimators=100;, score=-44.147 total time=   0.2s
# [CV 1/5] END max_depth=6, min_samples_leaf=0.1, n_estimators=200;, score=-44.448 total time=   0.4s
# [CV 2/5] END max_depth=6, min_samples_leaf=0.1, n_estimators=200;, score=-45.743 total time=   0.2s
# [CV 3/5] END max_depth=6, min_samples_leaf=0.1, n_estimators=200;, score=-44.829 total time=   0.2s
# [CV 4/5] END max_depth=6, min_samples_leaf=0.1, n_estimators=200;, score=-45.561 total time=   0.2s
# [CV 5/5] END max_depth=6, min_samples_leaf=0.1, n_estimators=200;, score=-44.660 total time=   0.2s
# [CV 1/5] END max_depth=12, min_samples_leaf=0.05, n_estimators=50;, score=-46.046 total time=   0.6s
# [CV 2/5] END max_depth=12, min_samples_leaf=0.05, n_estimators=50;, score=-47.020 total time=   0.7s
# [CV 3/5] END max_depth=12, min_samples_leaf=0.05, n_estimators=50;, score=-46.517 total time=   0.5s
# [CV 4/5] END max_depth=12, min_samples_leaf=0.05, n_estimators=50;, score=-46.270 total time=   0.5s
# [CV 5/5] END max_depth=12, min_samples_leaf=0.05, n_estimators=50;, score=-45.967 total time=   0.6s
# [CV 1/5] END max_depth=12, min_samples_leaf=0.05, n_estimators=100;, score=-46.626 total time=   0.9s
# [CV 2/5] END max_depth=12, min_samples_leaf=0.05, n_estimators=100;, score=-47.607 total time=   0.9s
# [CV 3/5] END max_depth=12, min_samples_leaf=0.05, n_estimators=100;, score=-47.005 total time=   1.1s
# [CV 4/5] END max_depth=12, min_samples_leaf=0.05, n_estimators=100;, score=-46.759 total time=   1.1s
# [CV 5/5] END max_depth=12, min_samples_leaf=0.05, n_estimators=100;, score=-46.487 total time=   1.1s
# [CV 1/5] END max_depth=12, min_samples_leaf=0.05, n_estimators=200;, score=-47.063 total time=   1.9s
# [CV 2/5] END max_depth=12, min_samples_leaf=0.05, n_estimators=200;, score=-47.975 total time=   2.0s
# [CV 3/5] END max_depth=12, min_samples_leaf=0.05, n_estimators=200;, score=-47.369 total time=   1.9s
# [CV 4/5] END max_depth=12, min_samples_leaf=0.05, n_estimators=200;, score=-47.141 total time=   2.2s
# [CV 5/5] END max_depth=12, min_samples_leaf=0.05, n_estimators=200;, score=-46.934 total time=   2.2s
# [CV 1/5] END max_depth=12, min_samples_leaf=0.1, n_estimators=50;, score=-46.046 total time=   0.5s
# [CV 2/5] END max_depth=12, min_samples_leaf=0.1, n_estimators=50;, score=-47.020 total time=   0.5s
# [CV 3/5] END max_depth=12, min_samples_leaf=0.1, n_estimators=50;, score=-46.517 total time=   0.7s
# [CV 4/5] END max_depth=12, min_samples_leaf=0.1, n_estimators=50;, score=-46.270 total time=   0.5s
# [CV 5/5] END max_depth=12, min_samples_leaf=0.1, n_estimators=50;, score=-45.967 total time=   0.6s
# [CV 1/5] END max_depth=12, min_samples_leaf=0.1, n_estimators=100;, score=-46.626 total time=   0.9s
# [CV 2/5] END max_depth=12, min_samples_leaf=0.1, n_estimators=100;, score=-47.607 total time=   1.0s
# [CV 3/5] END max_depth=12, min_samples_leaf=0.1, n_estimators=100;, score=-47.005 total time=   0.9s
# [CV 4/5] END max_depth=12, min_samples_leaf=0.1, n_estimators=100;, score=-46.759 total time=   0.9s
# [CV 5/5] END max_depth=12, min_samples_leaf=0.1, n_estimators=100;, score=-46.487 total time=   0.9s
# [CV 1/5] END max_depth=12, min_samples_leaf=0.1, n_estimators=200;, score=-47.063 total time=   1.7s
# [CV 2/5] END max_depth=12, min_samples_leaf=0.1, n_estimators=200;, score=-47.975 total time=   1.7s
# [CV 3/5] END max_depth=12, min_samples_leaf=0.1, n_estimators=200;, score=-47.369 total time=   1.7s
# [CV 4/5] END max_depth=12, min_samples_leaf=0.1, n_estimators=200;, score=-47.141 total time=   2.0s
# [CV 5/5] END max_depth=12, min_samples_leaf=0.1, n_estimators=200;, score=-46.934 total time=   1.9s
# [CV 1/5] END max_depth=28, min_samples_leaf=0.05, n_estimators=50;, score=-47.751 total time=  17.7s
# [CV 2/5] END max_depth=28, min_samples_leaf=0.05, n_estimators=50;, score=-49.113 total time=  16.8s
# [CV 3/5] END max_depth=28, min_samples_leaf=0.05, n_estimators=50;, score=-48.906 total time=  15.4s
# [CV 4/5] END max_depth=28, min_samples_leaf=0.05, n_estimators=50;, score=-49.010 total time=  16.5s
# [CV 5/5] END max_depth=28, min_samples_leaf=0.05, n_estimators=50;, score=-48.140 total time=  15.0s
# [CV 1/5] END max_depth=28, min_samples_leaf=0.05, n_estimators=100;, score=-47.752 total time=  18.2s
# [CV 2/5] END max_depth=28, min_samples_leaf=0.05, n_estimators=100;, score=-49.114 total time=  18.5s
# [CV 3/5] END max_depth=28, min_samples_leaf=0.05, n_estimators=100;, score=-48.907 total time=  16.4s
# [CV 4/5] END max_depth=28, min_samples_leaf=0.05, n_estimators=100;, score=-49.011 total time=  16.6s
# [CV 5/5] END max_depth=28, min_samples_leaf=0.05, n_estimators=100;, score=-48.140 total time=  15.3s
# [CV 1/5] END max_depth=28, min_samples_leaf=0.05, n_estimators=200;, score=-47.752 total time=  16.4s
# [CV 2/5] END max_depth=28, min_samples_leaf=0.05, n_estimators=200;, score=-49.114 total time=  15.3s
# [CV 3/5] END max_depth=28, min_samples_leaf=0.05, n_estimators=200;, score=-48.907 total time=  15.1s
# [CV 4/5] END max_depth=28, min_samples_leaf=0.05, n_estimators=200;, score=-49.011 total time=  16.0s
# [CV 5/5] END max_depth=28, min_samples_leaf=0.05, n_estimators=200;, score=-48.140 total time=  15.3s
# [CV 1/5] END max_depth=28, min_samples_leaf=0.1, n_estimators=50;, score=-47.751 total time=  15.3s
# [CV 2/5] END max_depth=28, min_samples_leaf=0.1, n_estimators=50;, score=-49.113 total time=  14.1s
# [CV 3/5] END max_depth=28, min_samples_leaf=0.1, n_estimators=50;, score=-48.906 total time=  14.1s
# [CV 4/5] END max_depth=28, min_samples_leaf=0.1, n_estimators=50;, score=-49.010 total time=  14.6s
# [CV 5/5] END max_depth=28, min_samples_leaf=0.1, n_estimators=50;, score=-48.140 total time=  14.1s
# [CV 1/5] END max_depth=28, min_samples_leaf=0.1, n_estimators=100;, score=-47.752 total time=  16.5s
# [CV 2/5] END max_depth=28, min_samples_leaf=0.1, n_estimators=100;, score=-49.114 total time=  15.5s
# [CV 3/5] END max_depth=28, min_samples_leaf=0.1, n_estimators=100;, score=-48.907 total time=  16.5s
# [CV 4/5] END max_depth=28, min_samples_leaf=0.1, n_estimators=100;, score=-49.011 total time=  17.4s
# [CV 5/5] END max_depth=28, min_samples_leaf=0.1, n_estimators=100;, score=-48.140 total time=  16.0s
# [CV 1/5] END max_depth=28, min_samples_leaf=0.1, n_estimators=200;, score=-47.752 total time=  17.8s
# [CV 2/5] END max_depth=28, min_samples_leaf=0.1, n_estimators=200;, score=-49.114 total time=  15.7s
# [CV 3/5] END max_depth=28, min_samples_leaf=0.1, n_estimators=200;, score=-48.907 total time=  15.4s
# [CV 4/5] END max_depth=28, min_samples_leaf=0.1, n_estimators=200;, score=-49.011 total time=  15.9s
# [CV 5/5] END max_depth=28, min_samples_leaf=0.1, n_estimators=200;, score=-48.140 total time=  15.1s
#     Best Params : {'max_depth': 6, 'min_samples_leaf': 0.05, 'n_estimators': 50}
#     Best Estimators : XGBRegressor(base_score=None, booster=None, callbacks=None,
#              colsample_bylevel=None, colsample_bynode=None,
#              colsample_bytree=None, device=None, early_stopping_rounds=None,
#              enable_categorical=False, eval_metric=None, feature_types=None,
#              feature_weights=None, gamma=None, grow_policy=None,
#              importance_type=None, interaction_constraints=None,
#              learning_rate=None, max_bin=None, max_cat_threshold=None,
#              max_cat_to_onehot=None, max_delta_step=None, max_depth=6,
#              max_leaves=None, min_child_weight=None, min_samples_leaf=0.05,
#              missing=nan, monotone_constraints=None, multi_strategy=None,
#              n_estimators=50, n_jobs=None, ...)
#
#  regression Tuning Summary
#     RF : RMSE=$-44.12 |  params={'max_depth': 12, 'min_samples_leaf': 5, 'n_estimators': 200}
#     XGB : RMSE=$-44.17 |  params={'max_depth': 6, 'min_samples_leaf': 0.05, 'n_estimators': 50}

# %% [markdown]
# #### 02) Classification Hparam Tuning

# %%
param_grids_cls = {
                    'RF' : {
                            'model' : RandomForestClassifier(random_state=RANDOM_STATE),
                            'params' : {
                                        'n_estimators' : [100, 200],
                                        'min_samples_leaf' : [1, 5],
                                        'max_depth' : [6, 8, 12]
                                        }
                    },
                    'XGB' : {
                            'model' : XGBClassifier(random_state=RANDOM_STATE),
                            'params' : {
                                        'n_estimators' : [50, 100, 200],
                                        'min_samples_leaf' : [0.05, 0.1],
                                        'max_depth' : [6, 12, 28]
                                        }
                    }
                }

kf = StratifiedKFold(
                n_splits=N_SPLITS,
                shuffle=True, random_state=RANDOM_STATE       
                )

cls_tuning_results = {}
for name, config in param_grids_cls.items():
    print(f"\n Training {name} model...")

#Grid Search Cross Validation
    grid_search = GridSearchCV(
                        estimator=config['model'],
                        param_grid=config['params'],
                        cv=kf, scoring='neg_root_mean_squared_error',
                        verbose=3
                     )
    grid_search.fit(X_train_cls, y_train_cls)

    cls_tuning_results[name] = {
                                'best_params' : grid_search.best_params_,
                                'best_cv_score' : grid_search.best_score_,
                                'best_estimator' : grid_search.best_estimator_
                                }
    
    print(f"    Best Params : {grid_search.best_params_}")
    print(f"    Best Estimators : {grid_search.best_estimator_}")

print("\n regression Tuning Summary")
for name, result in cls_tuning_results.items():
    print(f"    {name} : RMSE=${result['best_cv_score']:.2f} |  params={result['best_params']}")
